# %% [markdown]
# # Homework 3 - Which book would you recomend?

# %% [markdown]
# ![alt text](img/SA_GR_SE_NL.png "")

# %% [markdown]
# ##### **Authors:** Daniel Jiménez & Beatrice Nobille & Selim Yahiamessaoud
# ##### **Date:** 2020/12/06
# ##### **Subject:** Algorithmic Methods of Data Mining
# ##### **Data Science Master's programme**
# ##### **La Sapienza University of Rome**
# _____

# %% [markdown]
# This file contains the solution to all the five Challenges (and its corresponding literals) required for the web scrapping and search engine creation for the Best Books ever list that you can find [HERE](https://www.goodreads.com/list/show/1.Best_Books_Ever?page=1)
#
# As like in any data-wrangling case, it's relevant to keep clean and tidy the working environment. We achieve this by explaining step-by-step the process we followed to crawl, parse and store the attributes of the books.
#
# **Notes:**
# - We worked on a PC with an SSD of 50 GB of free space and a RAM of 16 GB.
#
# Well, first thing first, we set the libraries that we will be using to perform all the web scraping and search engine creation.

# %% [markdown]
# # 1. Data collection

# %% [markdown]
# First things first. We import the required libraries to solve the challenges.

# %%
# Import required libraries
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.firefox import GeckoDriverManager
import time
import csv
from bs4 import BeautifulSoup
import requests
import pathlib
import math
import os
import pandas as pd
import numpy as np
import re
from langdetect import detect
import our_functions

# %% [markdown]
# ## 1.1. Get the list of books
#
# To get the list of the links for each book we followed the next steps:
# 1. We used `Selenium`, opening a browser (Firefox) to access to the main page where the list of the Best Books Ever
# 2. Then, we look for all the links that are on the page that contains '/book/show/' which have the URL we are looking for
# 3. As there are repeated links (appearing in links itself and in the photo of the book) we removed the duplicated values
# 4. After running in a loop the steps 2 and 3 for each of the 300 first pages, we stored them in the file **books_urls.txt** to be used later. We avoided saving two links of that were out of the list but inside the comments. Those books are *The War of the Worlds* and The *Shack*
#
# Note: In some occasions, we used `time.sleep(n)` to force the PC to wait n seconds until the webpage has been completely loaded to avoid errors when looking for an object.

# %%
start_time = time.time()
# Open driver (in this case Firefox - need to be installed in the PC)
driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())

# Open in Firefox the desired url
href = 'https://www.goodreads.com/list/show/1.Best_Books_Ever?page=1'
driver.get(href)

# Pause execution while the page loads the content
time.sleep(12)

# Iterate over each page to retrieve book's links
urls = []
for i in range(300):
    partial_time1 = time.time()
    # Find all elements that contain a link inside a table (td)
    elements = driver.find_elements_by_xpath("//a[@href]")
    
    for elem in elements:
        # Retrieve the link
        link = elem.get_attribute("href")
        # Check if the link corresponds to a book
        if '/book/show/' in link:
            # Append each link found
            urls.append(link)
    
    # Click on "next" link to advance in each webpage
    driver.find_element_by_partial_link_text("next").click()
    
    # Pause execution while the page loads the content
    time.sleep(5)
    print("Retrieving page", i + 1, "/ 300 took", time.time() - partial_time1, "seconds")
    
# Remove duplicated links (keeping the order of appearence of each book's url)
# final_urls = list(set(urls))
final_urls = []
for i in urls:
    if i not in final_urls:
        final_urls.append(i)

# Close Firefox browser
driver.quit()

# Export links to txt file
with open('books_urls.txt', 'w') as f:
    for item in final_urls:
        # Avoid exporting the books added in the comments by the people (only two cases)
        if (item != 'https://www.goodreads.com/book/show/2510.The_War_of_the_Worlds' and item != 'https://www.goodreads.com/book/show/1812457.The_Shack'):
            f.write("%s\n" % item)

del urls, final_urls

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [WDM] - Driver [C:\Users\Daniel_Jimenez\.wdm\drivers\geckodriver\win64\v0.28.0\geckodriver.exe] found in cache
# Retrieving page 1 / 300 took 24.5305757522583 seconds
# Retrieving page 2 / 300 took 31.544260501861572 seconds
# Retrieving page 3 / 300 took 30.777462482452393 seconds
# Retrieving page 4 / 300 took 27.54737663269043 seconds
# Retrieving page 5 / 300 took 30.077595710754395 seconds
# Retrieving page 6 / 300 took 26.381412029266357 seconds
# Retrieving page 7 / 300 took 26.7865309715271 seconds
# Retrieving page 8 / 300 took 24.992651224136353 seconds
# Retrieving page 9 / 300 took 29.19309949874878 seconds
# Retrieving page 10 / 300 took 28.588332414627075 seconds
# Retrieving page 11 / 300 took 28.364408493041992 seconds
# Retrieving page 12 / 300 took 27.344547986984253 seconds
# Retrieving page 13 / 300 took 26.75330424308777 seconds
# Retrieving page 14 / 300 took 29.226094007492065 seconds
# Retrieving page 15 / 300 took 26.680985689163208 seconds
# Retrieving page 16 / 300 took 25.645787715911865 seconds
# Retrieving page 17 / 300 took 25.48965358734131 seconds
# Retrieving page 18 / 300 took 24.455013275146484 seconds
# Retrieving page 19 / 300 took 28.921236753463745 seconds
# Retrieving page 20 / 300 took 25.605358600616455 seconds
# Retrieving page 21 / 300 took 24.36791968345642 seconds
# Retrieving page 22 / 300 took 27.436904907226562 seconds
# Retrieving page 23 / 300 took 28.920556783676147 seconds
# Retrieving page 24 / 300 took 25.840729236602783 seconds
# Retrieving page 25 / 300 took 25.12727975845337 seconds
# Retrieving page 26 / 300 took 25.933403491973877 seconds
# Retrieving page 27 / 300 took 25.81672239303589 seconds
# Retrieving page 28 / 300 took 24.892011404037476 seconds
# Retrieving page 29 / 300 took 25.064342498779297 seconds
# Retrieving page 30 / 300 took 25.437621355056763 seconds
# Retrieving page 31 / 300 took 24.8117356300354 seconds
# Retrieving page 32 / 300 took 25.42073678970337 seconds
# Retrieving page 33 / 300 took 25.787023305892944 seconds
# Retrieving page 34 / 300 took 24.855467319488525 seconds
# Retrieving page 35 / 300 took 24.87397599220276 seconds
# Retrieving page 36 / 300 took 24.140053749084473 seconds
# Retrieving page 37 / 300 took 24.41852831840515 seconds
# Retrieving page 38 / 300 took 26.94256567955017 seconds
# Retrieving page 39 / 300 took 24.64279055595398 seconds
# Retrieving page 40 / 300 took 27.992552995681763 seconds
# Retrieving page 41 / 300 took 26.32840085029602 seconds
# Retrieving page 42 / 300 took 27.365092515945435 seconds
# Retrieving page 43 / 300 took 26.543003797531128 seconds
# Retrieving page 44 / 300 took 25.926373720169067 seconds
# Retrieving page 45 / 300 took 26.350346326828003 seconds
# Retrieving page 46 / 300 took 25.391409397125244 seconds
# Retrieving page 47 / 300 took 27.15842580795288 seconds
# Retrieving page 48 / 300 took 25.53212022781372 seconds
# Retrieving page 49 / 300 took 25.89944839477539 seconds
# Retrieving page 50 / 300 took 27.56643581390381 seconds
# Retrieving page 51 / 300 took 27.50947117805481 seconds
# Retrieving page 52 / 300 took 26.93769669532776 seconds
# Retrieving page 53 / 300 took 28.05112361907959 seconds
# Retrieving page 54 / 300 took 27.126965045928955 seconds
# Retrieving page 55 / 300 took 25.86455774307251 seconds
# Retrieving page 56 / 300 took 27.96057653427124 seconds
# Retrieving page 57 / 300 took 29.12205958366394 seconds
# Retrieving page 58 / 300 took 26.785210847854614 seconds
# Retrieving page 59 / 300 took 27.648298740386963 seconds
# Retrieving page 60 / 300 took 28.694778203964233 seconds
# Retrieving page 61 / 300 took 28.88273572921753 seconds
# Retrieving page 62 / 300 took 28.651251792907715 seconds
# Retrieving page 63 / 300 took 26.702871322631836 seconds
# Retrieving page 64 / 300 took 25.7102313041687 seconds
# Retrieving page 65 / 300 took 25.56476664543152 seconds
# Retrieving page 66 / 300 took 28.879840850830078 seconds
# Retrieving page 67 / 300 took 28.09341835975647 seconds
# Retrieving page 68 / 300 took 26.44825005531311 seconds
# Retrieving page 69 / 300 took 26.16715693473816 seconds
# Retrieving page 70 / 300 took 28.06830143928528 seconds
# Retrieving page 71 / 300 took 28.324193000793457 seconds
# Retrieving page 72 / 300 took 31.107048511505127 seconds
# Retrieving page 73 / 300 took 28.764241218566895 seconds
# Retrieving page 74 / 300 took 27.27770972251892 seconds
# Retrieving page 75 / 300 took 26.741700649261475 seconds
# Retrieving page 76 / 300 took 27.43593716621399 seconds
# Retrieving page 77 / 300 took 30.143268823623657 seconds
# Retrieving page 78 / 300 took 26.387381076812744 seconds
# Retrieving page 79 / 300 took 25.755542993545532 seconds
# Retrieving page 80 / 300 took 25.88091731071472 seconds
# Retrieving page 81 / 300 took 26.350005388259888 seconds
# Retrieving page 82 / 300 took 28.08340573310852 seconds
# Retrieving page 83 / 300 took 27.44410467147827 seconds
# Retrieving page 84 / 300 took 25.655750513076782 seconds
# Retrieving page 85 / 300 took 26.42484164237976 seconds
# Retrieving page 86 / 300 took 35.76645040512085 seconds
# Retrieving page 87 / 300 took 27.978410482406616 seconds
# Retrieving page 88 / 300 took 25.51278281211853 seconds
# Retrieving page 89 / 300 took 25.978254079818726 seconds
# Retrieving page 90 / 300 took 28.058595657348633 seconds
# Retrieving page 91 / 300 took 25.66538906097412 seconds
# Retrieving page 92 / 300 took 27.865405559539795 seconds
# Retrieving page 93 / 300 took 26.90067744255066 seconds
# Retrieving page 94 / 300 took 28.995564937591553 seconds
# Retrieving page 95 / 300 took 28.333616495132446 seconds
# Retrieving page 96 / 300 took 28.497554540634155 seconds
# Retrieving page 97 / 300 took 28.403064012527466 seconds
# Retrieving page 98 / 300 took 28.753795623779297 seconds
# Retrieving page 99 / 300 took 27.670291662216187 seconds
# Retrieving page 100 / 300 took 26.11833357810974 seconds
# Retrieving page 101 / 300 took 32.02287530899048 seconds
# Retrieving page 102 / 300 took 26.595476150512695 seconds
# Retrieving page 103 / 300 took 26.11147665977478 seconds
# Retrieving page 104 / 300 took 25.696921825408936 seconds
# Retrieving page 105 / 300 took 26.56560969352722 seconds
# Retrieving page 106 / 300 took 25.65953493118286 seconds
# Retrieving page 107 / 300 took 25.50894594192505 seconds
# Retrieving page 108 / 300 took 26.61783266067505 seconds
# Retrieving page 109 / 300 took 27.03693389892578 seconds
# Retrieving page 110 / 300 took 27.3713481426239 seconds
# Retrieving page 111 / 300 took 25.932572603225708 seconds
# Retrieving page 112 / 300 took 25.945534467697144 seconds
# Retrieving page 113 / 300 took 26.940762042999268 seconds
# Retrieving page 114 / 300 took 26.21585702896118 seconds
# Retrieving page 115 / 300 took 26.288719415664673 seconds
# Retrieving page 116 / 300 took 26.83178472518921 seconds
# Retrieving page 117 / 300 took 26.500583171844482 seconds
# Retrieving page 118 / 300 took 26.916226387023926 seconds
# Retrieving page 119 / 300 took 27.369621992111206 seconds
# Retrieving page 120 / 300 took 28.475521326065063 seconds
# Retrieving page 121 / 300 took 26.949249505996704 seconds
# Retrieving page 122 / 300 took 26.123276948928833 seconds
# Retrieving page 123 / 300 took 30.10991072654724 seconds
# Retrieving page 124 / 300 took 26.452583074569702 seconds
# Retrieving page 125 / 300 took 26.40884566307068 seconds
# Retrieving page 126 / 300 took 26.147671461105347 seconds
# Retrieving page 127 / 300 took 26.644237995147705 seconds
# Retrieving page 128 / 300 took 27.470280170440674 seconds
# Retrieving page 129 / 300 took 26.476136207580566 seconds
# Retrieving page 130 / 300 took 27.43202829360962 seconds
# Retrieving page 131 / 300 took 26.35567569732666 seconds
# Retrieving page 132 / 300 took 25.236947536468506 seconds
# Retrieving page 133 / 300 took 26.602054595947266 seconds
# Retrieving page 134 / 300 took 26.217074394226074 seconds
# Retrieving page 135 / 300 took 30.50624370574951 seconds
# Retrieving page 136 / 300 took 25.812974452972412 seconds
# Retrieving page 137 / 300 took 26.969828605651855 seconds
# Retrieving page 138 / 300 took 25.91697335243225 seconds
# Retrieving page 139 / 300 took 25.54599928855896 seconds
# Retrieving page 140 / 300 took 26.96252155303955 seconds
# Retrieving page 141 / 300 took 25.837315797805786 seconds
# Retrieving page 142 / 300 took 27.362890005111694 seconds
# Retrieving page 143 / 300 took 27.844377040863037 seconds
# Retrieving page 144 / 300 took 27.230116844177246 seconds
# Retrieving page 145 / 300 took 28.839641094207764 seconds
# Retrieving page 146 / 300 took 27.969048500061035 seconds
# Retrieving page 147 / 300 took 29.08222460746765 seconds
# Retrieving page 148 / 300 took 26.82687211036682 seconds
# Retrieving page 149 / 300 took 26.589679479599 seconds
# Retrieving page 150 / 300 took 26.605907440185547 seconds
# Retrieving page 151 / 300 took 26.322991371154785 seconds
# Retrieving page 152 / 300 took 25.947474241256714 seconds
# Retrieving page 153 / 300 took 33.886876344680786 seconds
# Retrieving page 154 / 300 took 27.153171062469482 seconds
# Retrieving page 155 / 300 took 26.04840397834778 seconds
# Retrieving page 156 / 300 took 26.280890464782715 seconds
# Retrieving page 157 / 300 took 26.49255681037903 seconds
# Retrieving page 158 / 300 took 26.443269729614258 seconds
# Retrieving page 159 / 300 took 26.74429988861084 seconds
# Retrieving page 160 / 300 took 26.19463586807251 seconds
# Retrieving page 161 / 300 took 28.718822479248047 seconds
# Retrieving page 162 / 300 took 25.948299646377563 seconds
# Retrieving page 163 / 300 took 26.655022859573364 seconds
# Retrieving page 164 / 300 took 26.480363130569458 seconds
# Retrieving page 165 / 300 took 25.812308073043823 seconds
# Retrieving page 166 / 300 took 27.381757020950317 seconds
# Retrieving page 167 / 300 took 26.26866316795349 seconds
# Retrieving page 168 / 300 took 30.61807918548584 seconds
# Retrieving page 169 / 300 took 25.75813388824463 seconds
# Retrieving page 170 / 300 took 25.906007766723633 seconds
# Retrieving page 171 / 300 took 26.555251121520996 seconds
# Retrieving page 172 / 300 took 25.66702437400818 seconds
# Retrieving page 173 / 300 took 25.996628522872925 seconds
# Retrieving page 174 / 300 took 26.79874610900879 seconds
# Retrieving page 175 / 300 took 25.06633996963501 seconds
# Retrieving page 176 / 300 took 27.16756510734558 seconds
# Retrieving page 177 / 300 took 26.251510620117188 seconds
# Retrieving page 178 / 300 took 26.22274374961853 seconds
# Retrieving page 179 / 300 took 26.789669036865234 seconds
# Retrieving page 180 / 300 took 27.037831783294678 seconds
# Retrieving page 181 / 300 took 28.99360203742981 seconds
# Retrieving page 182 / 300 took 26.12806010246277 seconds
# Retrieving page 183 / 300 took 29.2663094997406 seconds
# Retrieving page 184 / 300 took 27.48170018196106 seconds
# Retrieving page 185 / 300 took 27.230564832687378 seconds
# Retrieving page 186 / 300 took 28.01953101158142 seconds
# Retrieving page 187 / 300 took 27.638040781021118 seconds
# Retrieving page 188 / 300 took 28.081847190856934 seconds
# Retrieving page 189 / 300 took 26.28853440284729 seconds
# Retrieving page 190 / 300 took 27.275870084762573 seconds
# Retrieving page 191 / 300 took 26.363747358322144 seconds
# Retrieving page 192 / 300 took 25.527953624725342 seconds
# Retrieving page 193 / 300 took 26.939828872680664 seconds
# Retrieving page 194 / 300 took 26.643810272216797 seconds
# Retrieving page 195 / 300 took 26.95879292488098 seconds
# Retrieving page 196 / 300 took 26.411935091018677 seconds
# Retrieving page 197 / 300 took 26.67928910255432 seconds
# Retrieving page 198 / 300 took 26.99638557434082 seconds
# Retrieving page 199 / 300 took 26.130680084228516 seconds
# Retrieving page 200 / 300 took 26.96429133415222 seconds
# Retrieving page 201 / 300 took 26.599246740341187 seconds
# Retrieving page 202 / 300 took 26.531925439834595 seconds
# Retrieving page 203 / 300 took 26.997862100601196 seconds
# Retrieving page 204 / 300 took 26.72072434425354 seconds
# Retrieving page 205 / 300 took 30.556159257888794 seconds
# Retrieving page 206 / 300 took 26.7072491645813 seconds
# Retrieving page 207 / 300 took 27.961161613464355 seconds
# Retrieving page 208 / 300 took 29.966004610061646 seconds
# Retrieving page 209 / 300 took 30.376925706863403 seconds
# Retrieving page 210 / 300 took 27.575555324554443 seconds
# Retrieving page 211 / 300 took 28.73565673828125 seconds
# Retrieving page 212 / 300 took 29.12870144844055 seconds
# Retrieving page 213 / 300 took 27.368044137954712 seconds
# Retrieving page 214 / 300 took 27.1644389629364 seconds
# Retrieving page 215 / 300 took 26.32014536857605 seconds
# Retrieving page 216 / 300 took 26.89630937576294 seconds
# Retrieving page 217 / 300 took 27.629677057266235 seconds
# Retrieving page 218 / 300 took 28.316299438476562 seconds
# Retrieving page 219 / 300 took 33.462340354919434 seconds
# Retrieving page 220 / 300 took 31.035537481307983 seconds
# Retrieving page 221 / 300 took 31.723263025283813 seconds
# Retrieving page 222 / 300 took 29.489925384521484 seconds
# Retrieving page 223 / 300 took 30.69455599784851 seconds
# Retrieving page 224 / 300 took 29.686609268188477 seconds
# Retrieving page 225 / 300 took 29.3411066532135 seconds
# Retrieving page 226 / 300 took 28.415079832077026 seconds
# Retrieving page 227 / 300 took 28.375515699386597 seconds
# Retrieving page 228 / 300 took 30.778503894805908 seconds
# Retrieving page 229 / 300 took 28.3097882270813 seconds
# Retrieving page 230 / 300 took 26.952392101287842 seconds
# Retrieving page 231 / 300 took 26.46496343612671 seconds
# Retrieving page 232 / 300 took 28.576562643051147 seconds
# Retrieving page 233 / 300 took 27.897496700286865 seconds
# Retrieving page 234 / 300 took 26.96037530899048 seconds
# Retrieving page 235 / 300 took 27.271376848220825 seconds
# Retrieving page 236 / 300 took 27.60778570175171 seconds
# Retrieving page 237 / 300 took 28.943202018737793 seconds
# Retrieving page 238 / 300 took 28.07105588912964 seconds
# Retrieving page 239 / 300 took 27.10186266899109 seconds
# Retrieving page 240 / 300 took 26.258192539215088 seconds
# Retrieving page 241 / 300 took 29.662002086639404 seconds
# Retrieving page 242 / 300 took 27.26762580871582 seconds
# Retrieving page 243 / 300 took 26.57458996772766 seconds
# Retrieving page 244 / 300 took 27.79405379295349 seconds
# Retrieving page 245 / 300 took 26.00234031677246 seconds
# Retrieving page 246 / 300 took 26.79191541671753 seconds
# Retrieving page 247 / 300 took 26.997865676879883 seconds
# Retrieving page 248 / 300 took 28.810014247894287 seconds
# Retrieving page 249 / 300 took 26.996505975723267 seconds
# Retrieving page 250 / 300 took 28.30020046234131 seconds
# Retrieving page 251 / 300 took 26.65848970413208 seconds
# Retrieving page 252 / 300 took 26.01393461227417 seconds
# Retrieving page 253 / 300 took 25.803728818893433 seconds
# Retrieving page 254 / 300 took 26.61423945426941 seconds
# Retrieving page 255 / 300 took 26.285027265548706 seconds
# Retrieving page 256 / 300 took 27.41226863861084 seconds
# Retrieving page 257 / 300 took 26.008833169937134 seconds
# Retrieving page 258 / 300 took 26.82942533493042 seconds
# Retrieving page 259 / 300 took 26.66798734664917 seconds
# Retrieving page 260 / 300 took 26.47597599029541 seconds
# Retrieving page 261 / 300 took 26.857612133026123 seconds
# Retrieving page 262 / 300 took 26.388643741607666 seconds
# Retrieving page 263 / 300 took 25.889496326446533 seconds
# Retrieving page 264 / 300 took 27.712737560272217 seconds
# Retrieving page 265 / 300 took 25.653677701950073 seconds
# Retrieving page 266 / 300 took 27.132432460784912 seconds
# Retrieving page 267 / 300 took 26.08907985687256 seconds
# Retrieving page 268 / 300 took 25.44897985458374 seconds
# Retrieving page 269 / 300 took 26.32256507873535 seconds
# Retrieving page 270 / 300 took 25.97219181060791 seconds
# Retrieving page 271 / 300 took 27.402277946472168 seconds
# Retrieving page 272 / 300 took 26.088651418685913 seconds
# Retrieving page 273 / 300 took 26.216188430786133 seconds
# Retrieving page 274 / 300 took 27.235188961029053 seconds
# Retrieving page 275 / 300 took 27.18942952156067 seconds
# Retrieving page 276 / 300 took 27.330579042434692 seconds
# Retrieving page 277 / 300 took 26.35282588005066 seconds
# Retrieving page 278 / 300 took 29.45510482788086 seconds
# Retrieving page 279 / 300 took 28.796777486801147 seconds
# Retrieving page 280 / 300 took 26.394497394561768 seconds
# Retrieving page 281 / 300 took 30.464385986328125 seconds
# Retrieving page 282 / 300 took 28.56553077697754 seconds
# Retrieving page 283 / 300 took 27.717346906661987 seconds
# Retrieving page 284 / 300 took 27.832045316696167 seconds
# Retrieving page 285 / 300 took 26.67467761039734 seconds
# Retrieving page 286 / 300 took 26.314087390899658 seconds
# Retrieving page 287 / 300 took 28.874304056167603 seconds
# Retrieving page 288 / 300 took 27.245039463043213 seconds
# Retrieving page 289 / 300 took 28.952723026275635 seconds
# Retrieving page 290 / 300 took 27.304768800735474 seconds
# Retrieving page 291 / 300 took 27.800731658935547 seconds
# Retrieving page 292 / 300 took 27.008151054382324 seconds
# Retrieving page 293 / 300 took 26.151293992996216 seconds
# Retrieving page 294 / 300 took 26.82801127433777 seconds
# Retrieving page 295 / 300 took 28.82157039642334 seconds
# Retrieving page 296 / 300 took 27.68420147895813 seconds
# Retrieving page 297 / 300 took 26.739314317703247 seconds
# Retrieving page 298 / 300 took 27.407556295394897 seconds
# Retrieving page 299 / 300 took 32.39687657356262 seconds
# Retrieving page 300 / 300 took 25.884078979492188 seconds
# --- 8252.531904459 seconds ---

# %% [markdown]
# As shown, the process took a bit more that 2 hours. Now we are ready to crawl the books.

# %% [markdown]
# ## 1.2. Crawl books
# Now, we need to download in our PC, like HTML, all webpages for each of the books' URL retrieved. To do so, we followed the next way of thinking:
#
# 1. First, we need to upload the *books_urls.txt* containing the links to each book
# 2. Later, we create from Python the 300 folders to store each of the HTML files
# 3. With the combination of `BeautifulSoup` and `requests` we retrieved the content of each HTML to Python
# 4. Automatically, we stored each HTML file in the respective folder in our PC, to keep it tidy
# 5. The points 3 and 4 were executed for each of the 30.000 URLs
#
# Note: To run this process, we proceeded to create 4 different sessions in a single computer and executed the loop by chunks. In each chunk, we had to retrieve 7500 URLs. We used this "parallelization" technique to reduce the execution time.

# %%
# Read the file containing retrieved URLs
with open('books_urls.txt', newline='') as f:
    reader = csv.reader(f)
    final_urls = list(reader)

# %%
start_time = time.time()
# Create 300 folders to store the HTML files
for i in range(300):
    # Define path to create folders
    newpath = os.getcwd() + r'\data\HTML_files\page_' + str(i + 1)
    # Check if folder exists, if not, create it
    if not os.path.exists(newpath):
        os.makedirs(newpath)

# Populate each folder with the corresponding HTML books
for i in range(len(final_urls)):
# for i in range(14620,14621):
# for i in [23543,23918,23998,24472,25747,27954]:
    partial_time1 = time.time()
    # Get the link to retrieve
    link = ' '.join(map(str, final_urls[i]))
    
#     print(link)
    # Request the webpage
    page = requests.get(link)
    # Parse page to soup format
    soup = BeautifulSoup(page.text, features='lxml')
    # Calculate the page of the corresponding book
    page = math.ceil((i + 1) / 100)
    
    # Save each webpage as HTML in our PC
    f = open(r"data/HTML_files/page_" + str(page) + r"/book_" + str(i + 1) + r".html", "w", encoding='utf-8')
    f.write(str(soup.prettify()))
    f.close()
    
    print("Processing book", i + 1, "/ 30000 took", time.time() - partial_time1, "seconds")

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Processing book 23544 / 30000 took 1.2755396366119385 seconds
# Processing book 23919 / 30000 took 0.4957573413848877 seconds
# Processing book 23999 / 30000 took 1.281550407409668 seconds
# Processing book 24473 / 30000 took 0.9667823314666748 seconds
# Processing book 25748 / 30000 took 1.3054816722869873 seconds
# Processing book 27955 / 30000 took 1.397230625152588 seconds
# --- 6.751603603363037 seconds ---

# %% [markdown]
# The previous process consumed a total of 3 hours to download the 30.000 webpages. The next step is to parse all the information of the HTML files downloaded.

# %% [markdown]
# ## 1.3 Parse downloaded pages
#
#
# At this point, we are challenged to execute the parsing. It means, extract relevant information regarding the books that are stored in the HTML files.
#
# First, we defined a function that let us find and retrieve some interesting pieces of information regarding the books (12 attributes). The `scrap_book` function is a modification of the one that we created in LAB class. The latter is leveraged in the use of `find_all` functionality provided by `BeautifullSoup`. Besides, we included some `Try/Except` steps to handle the possible errors when any of the desired attributes of the book don't exist. Furthermore, we used the `langdetect` library to find out the language of each book's description. The definition of this function can be found in the file *our_functions.py*

# %% [markdown]
# Later, we continued with the next phases:
#
# 1. We used the function mentioned above to get the attributes for each book
# 2. Then, we appended in a .tsv file the result of the retrieved information of every book, separated by \t (TAB)
# 3. The prebious phases where executed for the whole 30.000 books
#
# Note: Again, we proceeded to initiate 4 sessions in a single computer and executed the loop by chunks. In each chunk, we had to look for the information of 7500 books each. As a result, we will have 4 .tsv files that need to be appended later.

# %%
start_time = time.time()

for i in range(0, 7500):
# for i in range(14,16):
    partial_time1 = time.time()

    # Calculate the page of the corresponding book
    page = math.ceil((i + 1) / 100)
    
    # Get the HTML of each book
    path = r"data/HTML_files/page_" + str(page) + r"/book_" + str(i + 1) + r".html"
    
    # Scrap the content
    info_book = our_functions.scrap_book(path)
    
    # Add the URL
    info_book = info_book + final_urls[i]
#     print(info_book)
    info_book =  '\t'.join(map(str,info_book)) + " \n"
    
    # Write in the txv file
    with open("data/tsv _files/final_df_1.tsv", "a", encoding='utf-8') as record_file:
        record_file.write(info_book)
    
    print("Processing book", i + 1, "/ 30000 took", time.time() - partial_time1, "seconds")

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Processing book 1 / 30000 took 1.7022335529327393 seconds
# Processing book 2 / 30000 took 1.4291777610778809 seconds
# Processing book 3 / 30000 took 0.8537194728851318 seconds
# Processing book 4 / 30000 took 1.0043158531188965 seconds
# Processing book 5 / 30000 took 1.0651531219482422 seconds
# Processing book 6 / 30000 took 1.2147505283355713 seconds
# Processing book 7 / 30000 took 0.7482569217681885 seconds
# Processing book 8 / 30000 took 1.0801126956939697 seconds
# Processing book 9 / 30000 took 0.5096359252929688 seconds
# Processing book 10 / 30000 took 0.5934140682220459 seconds
# Processing book 11 / 30000 took 0.873664379119873 seconds
# Processing book 12 / 30000 took 0.6901562213897705 seconds
# Processing book 13 / 30000 took 0.5106661319732666 seconds
# Processing book 14 / 30000 took 0.885603666305542 seconds
# Processing book 15 / 30000 took 0.710101842880249 seconds
# Processing book 16 / 30000 took 0.6263227462768555 seconds
# Processing book 17 / 30000 took 0.598400354385376 seconds
# Processing book 18 / 30000 took 0.8038520812988281 seconds
# Processing book 19 / 30000 took 0.8626940250396729 seconds
# Processing book 20 / 30000 took 0.8557648658752441 seconds
# Processing book 21 / 30000 took 0.6971406936645508 seconds
# Processing book 22 / 30000 took 0.80484938621521 seconds
# Processing book 23 / 30000 took 0.4091455936431885 seconds
# Processing book 24 / 30000 took 0.8926136493682861 seconds
# Processing book 25 / 30000 took 0.6412854194641113 seconds
# Processing book 26 / 30000 took 1.0491936206817627 seconds
# Processing book 27 / 30000 took 0.7868969440460205 seconds
# Processing book 28 / 30000 took 1.0341932773590088 seconds
# Processing book 29 / 30000 took 0.8856339454650879 seconds
# Processing book 30 / 30000 took 2.268739938735962 seconds
# Processing book 31 / 30000 took 1.6894822120666504 seconds
# Processing book 32 / 30000 took 1.5129568576812744 seconds
# Processing book 33 / 30000 took 0.5176141262054443 seconds
# Processing book 34 / 30000 took 0.581484317779541 seconds
# Processing book 35 / 30000 took 0.6006259918212891 seconds
# Processing book 36 / 30000 took 0.5934114456176758 seconds
# Processing book 37 / 30000 took 0.7420151233673096 seconds
# Processing book 38 / 30000 took 1.372596263885498 seconds
# Processing book 39 / 30000 took 0.5909106731414795 seconds
# Processing book 40 / 30000 took 0.8218047618865967 seconds
# Processing book 41 / 30000 took 0.7230653762817383 seconds
# Processing book 42 / 30000 took 0.8716700077056885 seconds
# Processing book 43 / 30000 took 0.8237996101379395 seconds
# Processing book 44 / 30000 took 0.7360312938690186 seconds
# Processing book 45 / 30000 took 0.6233339309692383 seconds
# Processing book 46 / 30000 took 1.4591498374938965 seconds
# Processing book 47 / 30000 took 0.7041187286376953 seconds
# Processing book 48 / 30000 took 0.47876620292663574 seconds
# Processing book 49 / 30000 took 0.6069939136505127 seconds
# Processing book 50 / 30000 took 0.5724682807922363 seconds
# Processing book 51 / 30000 took 0.3261280059814453 seconds
# Processing book 52 / 30000 took 0.40691399574279785 seconds
# Processing book 53 / 30000 took 1.2886559963226318 seconds
# Processing book 54 / 30000 took 0.39594435691833496 seconds
# Processing book 55 / 30000 took 0.4429187774658203 seconds
# Processing book 56 / 30000 took 0.7310967445373535 seconds
# Processing book 57 / 30000 took 0.5295345783233643 seconds
# Processing book 58 / 30000 took 0.5993945598602295 seconds
# Processing book 59 / 30000 took 1.021303415298462 seconds
# Processing book 60 / 30000 took 0.6043491363525391 seconds
# Processing book 61 / 30000 took 0.5757522583007812 seconds
# Processing book 62 / 30000 took 0.5685446262359619 seconds
# Processing book 63 / 30000 took 0.4089055061340332 seconds
# Processing book 64 / 30000 took 0.7639591693878174 seconds
# Processing book 65 / 30000 took 1.0063552856445312 seconds
# Processing book 66 / 30000 took 1.223682165145874 seconds
# Processing book 67 / 30000 took 0.4896879196166992 seconds
# Processing book 68 / 30000 took 0.6652228832244873 seconds
# Processing book 69 / 30000 took 0.7320425510406494 seconds
# Processing book 70 / 30000 took 0.9544496536254883 seconds
# Processing book 71 / 30000 took 2.2540297508239746 seconds
# Processing book 72 / 30000 took 0.8236322402954102 seconds
# Processing book 73 / 30000 took 0.8489992618560791 seconds
# Processing book 74 / 30000 took 0.8397543430328369 seconds
# Processing book 75 / 30000 took 1.233701467514038 seconds
# Processing book 76 / 30000 took 0.6442768573760986 seconds
# Processing book 77 / 30000 took 0.8896236419677734 seconds
# Processing book 78 / 30000 took 1.4291813373565674 seconds
# Processing book 79 / 30000 took 1.0722899436950684 seconds
# Processing book 80 / 30000 took 1.2371656894683838 seconds
# Processing book 81 / 30000 took 1.5448718070983887 seconds
# Processing book 82 / 30000 took 0.8507235050201416 seconds
# Processing book 83 / 30000 took 0.7051148414611816 seconds
# Processing book 84 / 30000 took 1.111604928970337 seconds
# Processing book 85 / 30000 took 1.3613617420196533 seconds
# Processing book 86 / 30000 took 1.301520824432373 seconds
# Processing book 87 / 30000 took 1.9497904777526855 seconds
# Processing book 88 / 30000 took 0.7151358127593994 seconds
# Processing book 89 / 30000 took 0.675194263458252 seconds
# Processing book 90 / 30000 took 0.6423244476318359 seconds
# Processing book 91 / 30000 took 0.7888526916503906 seconds
# Processing book 92 / 30000 took 1.3464031219482422 seconds
# Processing book 93 / 30000 took 1.1229963302612305 seconds
# Processing book 94 / 30000 took 1.0023210048675537 seconds
# Processing book 95 / 30000 took 0.5176153182983398 seconds
# Processing book 96 / 30000 took 0.46498680114746094 seconds
# Processing book 97 / 30000 took 0.5249333381652832 seconds
# Processing book 98 / 30000 took 0.4059164524078369 seconds
# Processing book 99 / 30000 took 0.655247688293457 seconds
# Processing book 100 / 30000 took 0.33809757232666016 seconds
# Processing book 101 / 30000 took 1.329479694366455 seconds
# Processing book 102 / 30000 took 0.4198431968688965 seconds
# Processing book 103 / 30000 took 1.1060447692871094 seconds
# Processing book 104 / 30000 took 0.575462818145752 seconds
# Processing book 105 / 30000 took 0.7929201126098633 seconds
# Processing book 106 / 30000 took 1.2586355209350586 seconds
# Processing book 107 / 30000 took 0.8317751884460449 seconds
# Processing book 108 / 30000 took 0.587468147277832 seconds
# Processing book 109 / 30000 took 0.5245974063873291 seconds
# Processing book 110 / 30000 took 1.0671489238739014 seconds
# Processing book 111 / 30000 took 0.7300479412078857 seconds
# Processing book 112 / 30000 took 0.7160863876342773 seconds
# Processing book 113 / 30000 took 1.1898188591003418 seconds
# Processing book 114 / 30000 took 1.443143367767334 seconds
# Processing book 115 / 30000 took 1.2654337882995605 seconds
# Processing book 116 / 30000 took 1.144939661026001 seconds
# Processing book 117 / 30000 took 0.5146732330322266 seconds
# Processing book 118 / 30000 took 0.8669073581695557 seconds
# Processing book 119 / 30000 took 0.7250614166259766 seconds
# Processing book 120 / 30000 took 0.9315106868743896 seconds
# Processing book 121 / 30000 took 0.7390236854553223 seconds
# Processing book 122 / 30000 took 0.5076107978820801 seconds
# Processing book 123 / 30000 took 0.7619626522064209 seconds
# Processing book 124 / 30000 took 0.6073775291442871 seconds
# Processing book 125 / 30000 took 0.7612128257751465 seconds
# Processing book 126 / 30000 took 0.4767270088195801 seconds
# Processing book 127 / 30000 took 1.4122271537780762 seconds
# Processing book 128 / 30000 took 0.9445109367370605 seconds
# Processing book 129 / 30000 took 0.5375287532806396 seconds
# Processing book 130 / 30000 took 0.7310459613800049 seconds
# Processing book 131 / 30000 took 0.5126256942749023 seconds
# Processing book 132 / 30000 took 0.5455389022827148 seconds
# Processing book 133 / 30000 took 1.4152228832244873 seconds
# Processing book 134 / 30000 took 0.7480008602142334 seconds
# Processing book 135 / 30000 took 1.4650826454162598 seconds
# Processing book 136 / 30000 took 2.1073665618896484 seconds
# Processing book 137 / 30000 took 1.3743252754211426 seconds
# Processing book 138 / 30000 took 1.051835298538208 seconds
# Processing book 139 / 30000 took 0.8357646465301514 seconds
# Processing book 140 / 30000 took 1.132972240447998 seconds
# Processing book 141 / 30000 took 1.5817723274230957 seconds
# Processing book 142 / 30000 took 1.722395658493042 seconds
# Processing book 143 / 30000 took 1.8537240028381348 seconds
# Processing book 144 / 30000 took 2.6494152545928955 seconds
# Processing book 145 / 30000 took 1.7513201236724854 seconds
# Processing book 146 / 30000 took 1.1860918998718262 seconds
# Processing book 147 / 30000 took 0.6634023189544678 seconds
# Processing book 148 / 30000 took 1.0661497116088867 seconds
# Processing book 149 / 30000 took 0.4886932373046875 seconds
# Processing book 150 / 30000 took 0.7649543285369873 seconds
# Processing book 151 / 30000 took 1.2935419082641602 seconds
# Processing book 152 / 30000 took 1.320472002029419 seconds
# Processing book 153 / 30000 took 1.0930769443511963 seconds
# Processing book 154 / 30000 took 0.599400520324707 seconds
# Processing book 155 / 30000 took 0.7410194873809814 seconds
# Processing book 156 / 30000 took 1.3743228912353516 seconds
# Processing book 157 / 30000 took 0.6871616840362549 seconds
# Processing book 158 / 30000 took 0.7061121463775635 seconds
# Processing book 159 / 30000 took 0.8666832447052002 seconds
# Processing book 160 / 30000 took 0.6771869659423828 seconds
# Processing book 161 / 30000 took 0.82485032081604 seconds
# Processing book 162 / 30000 took 1.440413236618042 seconds
# Processing book 163 / 30000 took 1.2446727752685547 seconds
# Processing book 164 / 30000 took 0.7210733890533447 seconds
# Processing book 165 / 30000 took 2.4095587730407715 seconds
# Processing book 166 / 30000 took 0.8078405857086182 seconds
# Processing book 167 / 30000 took 1.72281813621521 seconds
# Processing book 168 / 30000 took 1.7662782669067383 seconds
# Processing book 169 / 30000 took 0.8606984615325928 seconds
# Processing book 170 / 30000 took 1.2803540229797363 seconds
# Processing book 171 / 30000 took 0.7171943187713623 seconds
# Processing book 172 / 30000 took 0.8896231651306152 seconds
# Processing book 173 / 30000 took 2.317138671875 seconds
# Processing book 174 / 30000 took 1.4400780200958252 seconds
# Processing book 175 / 30000 took 0.9315063953399658 seconds
# Processing book 176 / 30000 took 0.807837963104248 seconds
# Processing book 177 / 30000 took 1.8769829273223877 seconds
# Processing book 178 / 30000 took 1.2955365180969238 seconds
# Processing book 179 / 30000 took 1.0192761421203613 seconds
# Processing book 180 / 30000 took 1.3743255138397217 seconds
# Processing book 181 / 30000 took 1.257638692855835 seconds
# Processing book 182 / 30000 took 1.016284465789795 seconds
# Processing book 183 / 30000 took 1.6096975803375244 seconds
# Processing book 184 / 30000 took 1.108036994934082 seconds
# Processing book 185 / 30000 took 0.9185435771942139 seconds
# Processing book 186 / 30000 took 1.46907377243042 seconds
# Processing book 187 / 30000 took 1.2067737579345703 seconds
# Processing book 188 / 30000 took 2.9132137298583984 seconds
# Processing book 189 / 30000 took 2.661884069442749 seconds
# Processing book 190 / 30000 took 1.7024509906768799 seconds
# Processing book 191 / 30000 took 2.000652313232422 seconds
# Processing book 192 / 30000 took 24.997329235076904 seconds
# Processing book 193 / 30000 took 1.3344333171844482 seconds
# Processing book 194 / 30000 took 2.394599437713623 seconds
# Processing book 195 / 30000 took 1.332437515258789 seconds
# Processing book 196 / 30000 took 2.8663389682769775 seconds
# Processing book 197 / 30000 took 0.7689447402954102 seconds
# Processing book 198 / 30000 took 0.8926138877868652 seconds
# Processing book 199 / 30000 took 1.2905504703521729 seconds
# Processing book 200 / 30000 took 2.8952603340148926 seconds
# Processing book 201 / 30000 took 2.281899929046631 seconds
# Processing book 202 / 30000 took 1.4411485195159912 seconds
# Processing book 203 / 30000 took 1.934828758239746 seconds
# Processing book 204 / 30000 took 2.169200897216797 seconds
# Processing book 205 / 30000 took 0.6522557735443115 seconds
# Processing book 206 / 30000 took 1.275590181350708 seconds
# Processing book 207 / 30000 took 1.5787816047668457 seconds
# Processing book 208 / 30000 took 1.7991902828216553 seconds
# Processing book 209 / 30000 took 0.8776533603668213 seconds
# Processing book 210 / 30000 took 1.0222668647766113 seconds
# Processing book 211 / 30000 took 2.4504504203796387 seconds
# Processing book 212 / 30000 took 1.1160173416137695 seconds
# Processing book 213 / 30000 took 1.5757818222045898 seconds
# Processing book 214 / 30000 took 2.4903433322906494 seconds
# Processing book 215 / 30000 took 1.657569408416748 seconds
# Processing book 216 / 30000 took 1.149925947189331 seconds
# Processing book 217 / 30000 took 1.5967328548431396 seconds
# Processing book 218 / 30000 took 1.5398833751678467 seconds
# Processing book 219 / 30000 took 1.3533835411071777 seconds
# Processing book 220 / 30000 took 1.833099126815796 seconds
# Processing book 221 / 30000 took 1.3254566192626953 seconds
# Processing book 222 / 30000 took 0.7719357013702393 seconds
# Processing book 223 / 30000 took 2.321793556213379 seconds
# Processing book 224 / 30000 took 2.141274929046631 seconds
# Processing book 225 / 30000 took 1.6037132740020752 seconds
# Processing book 226 / 30000 took 1.7493228912353516 seconds
# Processing book 227 / 30000 took 2.588082790374756 seconds
# Processing book 228 / 30000 took 1.1060431003570557 seconds
# Processing book 229 / 30000 took 1.4910144805908203 seconds
# Processing book 230 / 30000 took 1.3952701091766357 seconds
# Processing book 231 / 30000 took 1.7991902828216553 seconds
# Processing book 232 / 30000 took 0.9993290901184082 seconds
# Processing book 233 / 30000 took 0.8856332302093506 seconds
# Processing book 234 / 30000 took 1.2935426235198975 seconds
# Processing book 235 / 30000 took 1.024263858795166 seconds
# Processing book 236 / 30000 took 0.9354987144470215 seconds
# Processing book 237 / 30000 took 1.6356275081634521 seconds
# Processing book 238 / 30000 took 1.7273826599121094 seconds
# Processing book 239 / 30000 took 0.7739307880401611 seconds
# Processing book 240 / 30000 took 0.8966033458709717 seconds
# Processing book 241 / 30000 took 1.0491952896118164 seconds
# Processing book 242 / 30000 took 0.8118295669555664 seconds
# Processing book 243 / 30000 took 0.9195418357849121 seconds
# Processing book 244 / 30000 took 1.2735955715179443 seconds
# Processing book 245 / 30000 took 1.33443284034729 seconds
# Processing book 246 / 30000 took 1.5817720890045166 seconds
# Processing book 247 / 30000 took 1.4969985485076904 seconds
# Processing book 248 / 30000 took 43.507705211639404 seconds
# Processing book 249 / 30000 took 1.0312440395355225 seconds
# Processing book 250 / 30000 took 1.292543888092041 seconds
# Processing book 251 / 30000 took 1.328449010848999 seconds
# Processing book 252 / 30000 took 1.3892853260040283 seconds
# Processing book 253 / 30000 took 1.708432912826538 seconds
# Processing book 254 / 30000 took 0.8846340179443359 seconds
# Processing book 255 / 30000 took 1.991675853729248 seconds
# Processing book 256 / 30000 took 1.2646198272705078 seconds
# Processing book 257 / 30000 took 1.1997942924499512 seconds
# Processing book 258 / 30000 took 1.3144853115081787 seconds
# Processing book 259 / 30000 took 1.1918134689331055 seconds
# Processing book 260 / 30000 took 1.650587797164917 seconds
# Processing book 261 / 30000 took 1.0511915683746338 seconds
# Processing book 262 / 30000 took 0.7819085121154785 seconds
# Processing book 263 / 30000 took 0.7300479412078857 seconds
# Processing book 264 / 30000 took 1.7762515544891357 seconds
# Processing book 265 / 30000 took 1.1030499935150146 seconds
# Processing book 266 / 30000 took 1.4650835990905762 seconds
# Processing book 267 / 30000 took 1.5139524936676025 seconds
# Processing book 268 / 30000 took 0.8636908531188965 seconds
# Processing book 269 / 30000 took 1.1439414024353027 seconds
# Processing book 270 / 30000 took 1.4341669082641602 seconds
# Processing book 271 / 30000 took 1.4630882740020752 seconds
# Processing book 272 / 30000 took 0.6612319946289062 seconds
# Processing book 273 / 30000 took 0.9185452461242676 seconds
# Processing book 274 / 30000 took 1.6426095962524414 seconds
# Processing book 275 / 30000 took 0.9983322620391846 seconds
# Processing book 276 / 30000 took 1.5997238159179688 seconds
# Processing book 277 / 30000 took 2.990997076034546 seconds
# Processing book 278 / 30000 took 0.9205389022827148 seconds
# Processing book 279 / 30000 took 0.7689435482025146 seconds
# Processing book 280 / 30000 took 1.3364276885986328 seconds
# Processing book 281 / 30000 took 1.358368158340454 seconds
# Processing book 282 / 30000 took 1.801184892654419 seconds
# Processing book 283 / 30000 took 0.8208067417144775 seconds
# Processing book 284 / 30000 took 1.1359615325927734 seconds
# Processing book 285 / 30000 took 1.0452075004577637 seconds
# Processing book 286 / 30000 took 1.5707993507385254 seconds
# Processing book 287 / 30000 took 1.9328327178955078 seconds
# Processing book 288 / 30000 took 0.9773874282836914 seconds
# Processing book 289 / 30000 took 1.2027852535247803 seconds
# Processing book 290 / 30000 took 1.6894831657409668 seconds
# Processing book 291 / 30000 took 1.1130244731903076 seconds
# Processing book 292 / 30000 took 1.2676126956939697 seconds
# Processing book 293 / 30000 took 1.75730299949646 seconds
# Processing book 294 / 30000 took 0.7110984325408936 seconds
# Processing book 295 / 30000 took 1.4291799068450928 seconds
# Processing book 296 / 30000 took 1.0272538661956787 seconds
# Processing book 297 / 30000 took 0.9993298053741455 seconds
# Processing book 298 / 30000 took 3.706094741821289 seconds
# Processing book 299 / 30000 took 1.6515848636627197 seconds
# Processing book 300 / 30000 took 1.8580336570739746 seconds
# Processing book 301 / 30000 took 1.6077022552490234 seconds
# Processing book 302 / 30000 took 1.9049086570739746 seconds
# Processing book 303 / 30000 took 1.838085412979126 seconds
# Processing book 304 / 30000 took 1.6286466121673584 seconds
# Processing book 305 / 30000 took 1.5199365615844727 seconds
# Processing book 306 / 30000 took 1.4610943794250488 seconds
# Processing book 307 / 30000 took 2.5322306156158447 seconds
# Processing book 308 / 30000 took 2.1512489318847656 seconds
# Processing book 309 / 30000 took 1.2107632160186768 seconds
# Processing book 310 / 30000 took 3.036881923675537 seconds
# Processing book 311 / 30000 took 3.071789026260376 seconds
# Processing book 312 / 30000 took 0.9135580062866211 seconds
# Processing book 313 / 30000 took 1.893937349319458 seconds
# Processing book 314 / 30000 took 1.330444097518921 seconds
# Processing book 315 / 30000 took 1.9118893146514893 seconds
# Processing book 316 / 30000 took 1.964750051498413 seconds
# Processing book 317 / 30000 took 2.80250883102417 seconds
# Processing book 318 / 30000 took 1.8829658031463623 seconds
# Processing book 319 / 30000 took 1.3523848056793213 seconds
# Processing book 320 / 30000 took 2.747655153274536 seconds
# Processing book 321 / 30000 took 2.297856092453003 seconds
# Processing book 322 / 30000 took 2.566141128540039 seconds
# Processing book 323 / 30000 took 1.3434085845947266 seconds
# Processing book 324 / 30000 took 2.4853568077087402 seconds
# Processing book 325 / 30000 took 2.51328182220459 seconds
# Processing book 326 / 30000 took 2.6728549003601074 seconds
# Processing book 327 / 30000 took 1.927846908569336 seconds
# Processing book 328 / 30000 took 2.8972556591033936 seconds
# Processing book 329 / 30000 took 2.9361515045166016 seconds
# Processing book 330 / 30000 took 1.7293765544891357 seconds
# Processing book 331 / 30000 took 2.6010470390319824 seconds
# Processing book 332 / 30000 took 2.0205986499786377 seconds
# Processing book 333 / 30000 took 2.89127254486084 seconds
# Processing book 334 / 30000 took 1.76228928565979 seconds
# Processing book 335 / 30000 took 1.451122760772705 seconds
# Processing book 336 / 30000 took 3.478700637817383 seconds
# Processing book 337 / 30000 took 4.138935804367065 seconds
# Processing book 338 / 30000 took 2.401580810546875 seconds
# Processing book 339 / 30000 took 3.3749799728393555 seconds
# Processing book 340 / 30000 took 2.2100913524627686 seconds
# Processing book 341 / 30000 took 1.5109596252441406 seconds
# Processing book 342 / 30000 took 3.2592899799346924 seconds
# Processing book 343 / 30000 took 2.3277781009674072 seconds
# Processing book 344 / 30000 took 1.9148812294006348 seconds
# Processing book 345 / 30000 took 2.224055767059326 seconds
# Processing book 346 / 30000 took 1.3025174140930176 seconds
# Processing book 347 / 30000 took 2.3726589679718018 seconds
# Processing book 348 / 30000 took 1.7074358463287354 seconds
# Processing book 349 / 30000 took 2.0734572410583496 seconds
# Processing book 350 / 30000 took 1.3982625007629395 seconds
# Processing book 351 / 30000 took 1.2785825729370117 seconds
# Processing book 352 / 30000 took 1.7822353839874268 seconds
# Processing book 353 / 30000 took 1.6336324214935303 seconds
# Processing book 354 / 30000 took 2.3846285343170166 seconds
# Processing book 355 / 30000 took 1.13995361328125 seconds
# Processing book 356 / 30000 took 1.2067742347717285 seconds
# Processing book 357 / 30000 took 1.8919432163238525 seconds
# Processing book 358 / 30000 took 3.1605515480041504 seconds
# Processing book 359 / 30000 took 1.7323691844940186 seconds
# Processing book 360 / 30000 took 2.246992826461792 seconds
# Processing book 361 / 30000 took 1.9836978912353516 seconds
# Processing book 362 / 30000 took 1.047199010848999 seconds
# Processing book 363 / 30000 took 2.4684033393859863 seconds
# Processing book 364 / 30000 took 1.7712655067443848 seconds
# Processing book 365 / 30000 took 1.884960651397705 seconds
# Processing book 366 / 30000 took 1.3454036712646484 seconds
# Processing book 367 / 30000 took 1.6665475368499756 seconds
# Processing book 368 / 30000 took 1.542874813079834 seconds
# Processing book 369 / 30000 took 2.3128182888031006 seconds
# Processing book 370 / 30000 took 2.4245188236236572 seconds
# Processing book 371 / 30000 took 1.0083050727844238 seconds
# Processing book 372 / 30000 took 2.906231164932251 seconds
# Processing book 373 / 30000 took 1.0591683387756348 seconds
# Processing book 374 / 30000 took 2.202115058898926 seconds
# Processing book 375 / 30000 took 1.546865463256836 seconds
# Processing book 376 / 30000 took 1.5538456439971924 seconds
# Processing book 377 / 30000 took 1.992673397064209 seconds
# Processing book 378 / 30000 took 1.3763210773468018 seconds
# Processing book 379 / 30000 took 2.660886764526367 seconds
# Processing book 380 / 30000 took 1.110034704208374 seconds
# Processing book 381 / 30000 took 1.7283811569213867 seconds
# Processing book 382 / 30000 took 1.6376211643218994 seconds
# Processing book 383 / 30000 took 2.5820984840393066 seconds
# Processing book 384 / 30000 took 1.7702724933624268 seconds
# Processing book 385 / 30000 took 2.537217855453491 seconds
# Processing book 386 / 30000 took 1.1618938446044922 seconds
# Processing book 387 / 30000 took 3.9025678634643555 seconds
# Processing book 388 / 30000 took 2.395597219467163 seconds
# Processing book 389 / 30000 took 2.2589616775512695 seconds
# Processing book 390 / 30000 took 1.8390834331512451 seconds
# Processing book 391 / 30000 took 1.6735260486602783 seconds
# Processing book 392 / 30000 took 3.1695282459259033 seconds
# Processing book 393 / 30000 took 2.8972554206848145 seconds
# Processing book 394 / 30000 took 1.2725977897644043 seconds
# Processing book 395 / 30000 took 1.3773181438446045 seconds
# Processing book 396 / 30000 took 3.46174693107605 seconds
# Processing book 397 / 30000 took 1.9198675155639648 seconds
# Processing book 398 / 30000 took 1.349393367767334 seconds
# Processing book 399 / 30000 took 1.4202029705047607 seconds
# Processing book 400 / 30000 took 2.1013827323913574 seconds
# Processing book 401 / 30000 took 2.2509820461273193 seconds
# Processing book 402 / 30000 took 1.3513884544372559 seconds
# Processing book 403 / 30000 took 1.610694408416748 seconds
# Processing book 404 / 30000 took 2.097393751144409 seconds
# Processing book 405 / 30000 took 2.112352132797241 seconds
# Processing book 406 / 30000 took 1.5219299793243408 seconds
# Processing book 407 / 30000 took 1.9507853984832764 seconds
# Processing book 408 / 30000 took 2.350717067718506 seconds
# Processing book 409 / 30000 took 1.9148812294006348 seconds
# Processing book 410 / 30000 took 2.2380177974700928 seconds
# Processing book 411 / 30000 took 1.3892848491668701 seconds
# Processing book 412 / 30000 took 1.6485934257507324 seconds
# Processing book 413 / 30000 took 2.6559016704559326 seconds
# Processing book 414 / 30000 took 1.8450672626495361 seconds
# Processing book 415 / 30000 took 2.7985217571258545 seconds
# Processing book 416 / 30000 took 2.0435376167297363 seconds
# Processing book 417 / 30000 took 2.1572344303131104 seconds
# Processing book 418 / 30000 took 2.606034278869629 seconds
# Processing book 419 / 30000 took 1.6605620384216309 seconds
# Processing book 420 / 30000 took 2.2639477252960205 seconds
# Processing book 421 / 30000 took 1.9408128261566162 seconds
# Processing book 422 / 30000 took 1.8311045169830322 seconds
# Processing book 423 / 30000 took 1.692476511001587 seconds
# Processing book 424 / 30000 took 2.235025644302368 seconds
# Processing book 425 / 30000 took 1.6136853694915771 seconds
# Processing book 426 / 30000 took 4.065133810043335 seconds
# Processing book 427 / 30000 took 1.227717638015747 seconds
# Processing book 428 / 30000 took 2.4873504638671875 seconds
# Processing book 429 / 30000 took 2.0315704345703125 seconds
# Processing book 430 / 30000 took 1.189816951751709 seconds
# Processing book 431 / 30000 took 2.5621516704559326 seconds
# Processing book 432 / 30000 took 1.6545770168304443 seconds
# Processing book 433 / 30000 took 2.160224437713623 seconds
# Processing book 434 / 30000 took 1.9198682308197021 seconds
# Processing book 435 / 30000 took 3.4508490562438965 seconds
# Processing book 436 / 30000 took 1.6935522556304932 seconds
# Processing book 437 / 30000 took 3.035308599472046 seconds
# Processing book 438 / 30000 took 2.060856580734253 seconds
# Processing book 439 / 30000 took 2.908768892288208 seconds
# Processing book 440 / 30000 took 3.331376791000366 seconds
# Processing book 441 / 30000 took 1.406259536743164 seconds
# Processing book 442 / 30000 took 3.128915309906006 seconds
# Processing book 443 / 30000 took 1.4280362129211426 seconds
# Processing book 444 / 30000 took 1.6230049133300781 seconds
# Processing book 445 / 30000 took 1.2294797897338867 seconds
# Processing book 446 / 30000 took 2.346738576889038 seconds
# Processing book 447 / 30000 took 1.6550700664520264 seconds
# Processing book 448 / 30000 took 1.7807836532592773 seconds
# Processing book 449 / 30000 took 1.3129830360412598 seconds
# Processing book 450 / 30000 took 1.7351770401000977 seconds
# Processing book 451 / 30000 took 3.2902133464813232 seconds
# Processing book 452 / 30000 took 2.10264253616333 seconds
# Processing book 453 / 30000 took 2.2529876232147217 seconds
# Processing book 454 / 30000 took 1.9616787433624268 seconds
# Processing book 455 / 30000 took 2.1438357830047607 seconds
# Processing book 456 / 30000 took 2.1060101985931396 seconds
# Processing book 457 / 30000 took 2.8324196338653564 seconds
# Processing book 458 / 30000 took 2.8281760215759277 seconds
# Processing book 459 / 30000 took 2.253899097442627 seconds
# Processing book 460 / 30000 took 2.368091583251953 seconds
# Processing book 461 / 30000 took 1.296945333480835 seconds
# Processing book 462 / 30000 took 2.0364303588867188 seconds
# Processing book 463 / 30000 took 2.4464573860168457 seconds
# Processing book 464 / 30000 took 2.098735809326172 seconds
# Processing book 465 / 30000 took 2.0338134765625 seconds
# Processing book 466 / 30000 took 2.343057155609131 seconds
# Processing book 467 / 30000 took 3.0310304164886475 seconds
# Processing book 468 / 30000 took 3.1089582443237305 seconds
# Processing book 469 / 30000 took 1.2299683094024658 seconds
# Processing book 470 / 30000 took 1.6973066329956055 seconds
# Processing book 471 / 30000 took 1.4039306640625 seconds
# Processing book 472 / 30000 took 2.6349518299102783 seconds
# Processing book 473 / 30000 took 1.9499163627624512 seconds
# Processing book 474 / 30000 took 3.0061633586883545 seconds
# Processing book 475 / 30000 took 2.2439022064208984 seconds
# Processing book 476 / 30000 took 2.9581680297851562 seconds
# Processing book 477 / 30000 took 2.6328842639923096 seconds
# Processing book 478 / 30000 took 1.7299675941467285 seconds
# Processing book 479 / 30000 took 1.9030177593231201 seconds
# Processing book 480 / 30000 took 1.541914939880371 seconds
# Processing book 481 / 30000 took 2.040426015853882 seconds
# Processing book 482 / 30000 took 1.612468957901001 seconds
# Processing book 483 / 30000 took 2.0930023193359375 seconds
# Processing book 484 / 30000 took 1.4762005805969238 seconds
# Processing book 485 / 30000 took 1.7241201400756836 seconds
# Processing book 486 / 30000 took 3.183804512023926 seconds
# Processing book 487 / 30000 took 1.3528764247894287 seconds
# Processing book 488 / 30000 took 1.87400221824646 seconds
# Processing book 489 / 30000 took 2.0834274291992188 seconds
# Processing book 490 / 30000 took 1.7401442527770996 seconds
# Processing book 491 / 30000 took 1.4960565567016602 seconds
# Processing book 492 / 30000 took 1.4926834106445312 seconds
# Processing book 493 / 30000 took 1.5807580947875977 seconds
# Processing book 494 / 30000 took 1.6519920825958252 seconds
# Processing book 495 / 30000 took 2.6169774532318115 seconds
# Processing book 496 / 30000 took 0.944965124130249 seconds
# Processing book 497 / 30000 took 1.078376054763794 seconds
# Processing book 498 / 30000 took 1.7700324058532715 seconds
# Processing book 499 / 30000 took 2.793599843978882 seconds
# Processing book 500 / 30000 took 2.749175786972046 seconds
# Processing book 501 / 30000 took 2.642244815826416 seconds
# Processing book 502 / 30000 took 2.728604793548584 seconds
# Processing book 503 / 30000 took 1.6059188842773438 seconds
# Processing book 504 / 30000 took 2.636167287826538 seconds
# Processing book 505 / 30000 took 2.2458603382110596 seconds
# Processing book 506 / 30000 took 1.5690886974334717 seconds
# Processing book 507 / 30000 took 3.7380614280700684 seconds
# Processing book 508 / 30000 took 1.93013596534729 seconds
# Processing book 509 / 30000 took 2.215961217880249 seconds
# Processing book 510 / 30000 took 2.1112217903137207 seconds
# Processing book 511 / 30000 took 1.5927455425262451 seconds
# Processing book 512 / 30000 took 2.1811060905456543 seconds
# Processing book 513 / 30000 took 1.8728070259094238 seconds
# Processing book 514 / 30000 took 2.067776679992676 seconds
# Processing book 515 / 30000 took 2.8615942001342773 seconds
# Processing book 516 / 30000 took 4.1976540088653564 seconds
# Processing book 517 / 30000 took 2.4059479236602783 seconds
# Processing book 518 / 30000 took 1.711029052734375 seconds
# Processing book 519 / 30000 took 2.1463327407836914 seconds
# Processing book 520 / 30000 took 3.1678404808044434 seconds
# Processing book 521 / 30000 took 2.375260591506958 seconds
# Processing book 522 / 30000 took 2.0983550548553467 seconds
# Processing book 523 / 30000 took 1.739905595779419 seconds
# Processing book 524 / 30000 took 1.8313789367675781 seconds
# Processing book 525 / 30000 took 2.388965368270874 seconds
# Processing book 526 / 30000 took 2.11722469329834 seconds
# Processing book 527 / 30000 took 2.6919400691986084 seconds
# Processing book 528 / 30000 took 1.4118258953094482 seconds
# Processing book 529 / 30000 took 1.9012606143951416 seconds
# Processing book 530 / 30000 took 2.0871410369873047 seconds
# Processing book 531 / 30000 took 1.7839398384094238 seconds
# Processing book 532 / 30000 took 1.8368165493011475 seconds
# Processing book 533 / 30000 took 2.9162049293518066 seconds
# Processing book 534 / 30000 took 1.6592559814453125 seconds
# Processing book 535 / 30000 took 1.1446003913879395 seconds
# Processing book 536 / 30000 took 2.1117873191833496 seconds
# Processing book 537 / 30000 took 1.817068099975586 seconds
# Processing book 538 / 30000 took 2.751725912094116 seconds
# Processing book 539 / 30000 took 2.139321804046631 seconds
# Processing book 540 / 30000 took 2.2608888149261475 seconds
# Processing book 541 / 30000 took 2.9273221492767334 seconds
# Processing book 542 / 30000 took 1.3552234172821045 seconds
# Processing book 543 / 30000 took 2.1345865726470947 seconds
# Processing book 544 / 30000 took 2.6199378967285156 seconds
# Processing book 545 / 30000 took 1.7376277446746826 seconds
# Processing book 546 / 30000 took 2.1354756355285645 seconds
# Processing book 547 / 30000 took 2.086409330368042 seconds
# Processing book 548 / 30000 took 3.0915985107421875 seconds
# Processing book 549 / 30000 took 2.049943685531616 seconds
# Processing book 550 / 30000 took 3.252303123474121 seconds
# Processing book 551 / 30000 took 2.9600679874420166 seconds
# Processing book 552 / 30000 took 1.5879671573638916 seconds
# Processing book 553 / 30000 took 1.6017143726348877 seconds
# Processing book 554 / 30000 took 1.7408058643341064 seconds
# Processing book 555 / 30000 took 2.1574976444244385 seconds
# Processing book 556 / 30000 took 2.5887246131896973 seconds
# Processing book 557 / 30000 took 3.2907986640930176 seconds
# Processing book 558 / 30000 took 2.680835247039795 seconds
# Processing book 559 / 30000 took 1.6376221179962158 seconds
# Processing book 560 / 30000 took 2.4285085201263428 seconds
# Processing book 561 / 30000 took 1.8131537437438965 seconds
# Processing book 562 / 30000 took 2.0614895820617676 seconds
# Processing book 563 / 30000 took 1.7463312149047852 seconds
# Processing book 564 / 30000 took 0.9833722114562988 seconds
# Processing book 565 / 30000 took 2.189147710800171 seconds
# Processing book 566 / 30000 took 1.2456707954406738 seconds
# Processing book 567 / 30000 took 1.81315279006958 seconds
# Processing book 568 / 30000 took 1.5917448997497559 seconds
# Processing book 569 / 30000 took 1.8630189895629883 seconds
# Processing book 570 / 30000 took 2.754636287689209 seconds
# Processing book 571 / 30000 took 3.1845645904541016 seconds
# Processing book 572 / 30000 took 2.611524820327759 seconds
# Processing book 573 / 30000 took 1.9122848510742188 seconds
# Processing book 574 / 30000 took 2.473360776901245 seconds
# Processing book 575 / 30000 took 2.3006341457366943 seconds
# Processing book 576 / 30000 took 2.8962273597717285 seconds
# Processing book 577 / 30000 took 3.666086435317993 seconds
# Processing book 578 / 30000 took 3.4937262535095215 seconds
# Processing book 579 / 30000 took 2.3496041297912598 seconds
# Processing book 580 / 30000 took 1.4605982303619385 seconds
# Processing book 581 / 30000 took 3.516633987426758 seconds
# Processing book 582 / 30000 took 2.014052152633667 seconds
# Processing book 583 / 30000 took 2.112936496734619 seconds
# Processing book 584 / 30000 took 2.112485885620117 seconds
# Processing book 585 / 30000 took 2.342055320739746 seconds
# Processing book 586 / 30000 took 1.612194299697876 seconds
# Processing book 587 / 30000 took 2.5877814292907715 seconds
# Processing book 588 / 30000 took 2.358966827392578 seconds
# Processing book 589 / 30000 took 1.6020467281341553 seconds
# Processing book 590 / 30000 took 2.262901782989502 seconds
# Processing book 591 / 30000 took 3.3474247455596924 seconds
# Processing book 592 / 30000 took 2.093653917312622 seconds
# Processing book 593 / 30000 took 2.0474607944488525 seconds
# Processing book 594 / 30000 took 2.441659450531006 seconds
# Processing book 595 / 30000 took 1.6132299900054932 seconds
# Processing book 596 / 30000 took 2.067734479904175 seconds
# Processing book 597 / 30000 took 2.3749027252197266 seconds
# Processing book 598 / 30000 took 1.4160406589508057 seconds
# Processing book 599 / 30000 took 2.034092664718628 seconds
# Processing book 600 / 30000 took 2.216214418411255 seconds
# Processing book 601 / 30000 took 3.0682430267333984 seconds
# Processing book 602 / 30000 took 1.809058427810669 seconds
# Processing book 603 / 30000 took 1.886587142944336 seconds
# Processing book 604 / 30000 took 0.9830050468444824 seconds
# Processing book 605 / 30000 took 1.8672370910644531 seconds
# Processing book 606 / 30000 took 2.1193604469299316 seconds
# Processing book 607 / 30000 took 1.897639274597168 seconds
# Processing book 608 / 30000 took 1.360046625137329 seconds
# Processing book 609 / 30000 took 2.0420706272125244 seconds
# Processing book 610 / 30000 took 1.8453624248504639 seconds
# Processing book 611 / 30000 took 3.0065619945526123 seconds
# Processing book 612 / 30000 took 2.621494770050049 seconds
# Processing book 613 / 30000 took 1.552445411682129 seconds
# Processing book 614 / 30000 took 3.6290488243103027 seconds
# Processing book 615 / 30000 took 2.307344675064087 seconds
# Processing book 616 / 30000 took 1.8682520389556885 seconds
# Processing book 617 / 30000 took 2.0599489212036133 seconds
# Processing book 618 / 30000 took 2.2988975048065186 seconds
# Processing book 619 / 30000 took 3.409156560897827 seconds
# Processing book 620 / 30000 took 1.5731463432312012 seconds
# Processing book 621 / 30000 took 1.83467698097229 seconds
# Processing book 622 / 30000 took 2.505082130432129 seconds
# Processing book 623 / 30000 took 1.5720081329345703 seconds
# Processing book 624 / 30000 took 2.0101046562194824 seconds
# Processing book 625 / 30000 took 1.769819974899292 seconds
# Processing book 626 / 30000 took 2.9352917671203613 seconds
# Processing book 627 / 30000 took 4.278595924377441 seconds
# Processing book 628 / 30000 took 17.430622339248657 seconds
# Processing book 629 / 30000 took 2.9868597984313965 seconds
# Processing book 630 / 30000 took 2.0186843872070312 seconds
# Processing book 631 / 30000 took 3.925913095474243 seconds
# Processing book 632 / 30000 took 1.8750114440917969 seconds
# Processing book 633 / 30000 took 3.190066337585449 seconds
# Processing book 634 / 30000 took 2.328131914138794 seconds
# Processing book 635 / 30000 took 2.083854913711548 seconds
# Processing book 636 / 30000 took 1.9651048183441162 seconds
# Processing book 637 / 30000 took 2.441375255584717 seconds
# Processing book 638 / 30000 took 2.0298092365264893 seconds
# Processing book 639 / 30000 took 1.4740567207336426 seconds
# Processing book 640 / 30000 took 2.4498090744018555 seconds
# Processing book 641 / 30000 took 1.8840882778167725 seconds
# Processing book 642 / 30000 took 3.730137825012207 seconds
# Processing book 643 / 30000 took 2.3831286430358887 seconds
# Processing book 644 / 30000 took 1.878741979598999 seconds
# Processing book 645 / 30000 took 1.444836139678955 seconds
# Processing book 646 / 30000 took 2.6747026443481445 seconds
# Processing book 647 / 30000 took 1.2367758750915527 seconds
# Processing book 648 / 30000 took 1.5857112407684326 seconds
# Processing book 649 / 30000 took 1.8411037921905518 seconds
# Processing book 650 / 30000 took 1.9692819118499756 seconds
# Processing book 651 / 30000 took 2.2628235816955566 seconds
# Processing book 652 / 30000 took 1.4463698863983154 seconds
# Processing book 653 / 30000 took 1.9916646480560303 seconds
# Processing book 654 / 30000 took 2.3329885005950928 seconds
# Processing book 655 / 30000 took 1.216003656387329 seconds
# Processing book 656 / 30000 took 3.072038412094116 seconds
# Processing book 657 / 30000 took 1.9748802185058594 seconds
# Processing book 658 / 30000 took 2.4863476753234863 seconds
# Processing book 659 / 30000 took 2.614173650741577 seconds
# Processing book 660 / 30000 took 2.6880438327789307 seconds
# Processing book 661 / 30000 took 2.200740098953247 seconds
# Processing book 662 / 30000 took 1.557051420211792 seconds
# Processing book 663 / 30000 took 2.2748916149139404 seconds
# Processing book 664 / 30000 took 2.5771450996398926 seconds
# Processing book 665 / 30000 took 2.977046251296997 seconds
# Processing book 666 / 30000 took 2.076695203781128 seconds
# Processing book 667 / 30000 took 1.8374333381652832 seconds
# Processing book 668 / 30000 took 2.270132064819336 seconds
# Processing book 669 / 30000 took 2.2539448738098145 seconds
# Processing book 670 / 30000 took 2.9227828979492188 seconds
# Processing book 671 / 30000 took 2.611994743347168 seconds
# Processing book 672 / 30000 took 1.8351917266845703 seconds
# Processing book 673 / 30000 took 2.613485097885132 seconds
# Processing book 674 / 30000 took 2.0387520790100098 seconds
# Processing book 675 / 30000 took 1.729956865310669 seconds
# Processing book 676 / 30000 took 1.9012410640716553 seconds
# Processing book 677 / 30000 took 1.4106462001800537 seconds
# Processing book 678 / 30000 took 1.598297357559204 seconds
# Processing book 679 / 30000 took 1.5626590251922607 seconds
# Processing book 680 / 30000 took 1.4350612163543701 seconds
# Processing book 681 / 30000 took 1.9514179229736328 seconds
# Processing book 682 / 30000 took 2.1607651710510254 seconds
# Processing book 683 / 30000 took 2.186737537384033 seconds
# Processing book 684 / 30000 took 1.3984959125518799 seconds
# Processing book 685 / 30000 took 2.701820135116577 seconds
# Processing book 686 / 30000 took 1.1698334217071533 seconds
# Processing book 687 / 30000 took 1.9399917125701904 seconds
# Processing book 688 / 30000 took 1.6170237064361572 seconds
# Processing book 689 / 30000 took 0.94614577293396 seconds
# Processing book 690 / 30000 took 2.079458236694336 seconds
# Processing book 691 / 30000 took 1.8925633430480957 seconds
# Processing book 692 / 30000 took 1.3276853561401367 seconds
# Processing book 693 / 30000 took 2.22727108001709 seconds
# Processing book 694 / 30000 took 2.2380008697509766 seconds
# Processing book 695 / 30000 took 2.947045087814331 seconds
# Processing book 696 / 30000 took 1.35471510887146 seconds
# Processing book 697 / 30000 took 1.3471825122833252 seconds
# Processing book 698 / 30000 took 1.9341259002685547 seconds
# Processing book 699 / 30000 took 1.6173112392425537 seconds
# Processing book 700 / 30000 took 1.9328277111053467 seconds
# Processing book 701 / 30000 took 2.4747066497802734 seconds
# Processing book 702 / 30000 took 1.7074105739593506 seconds
# Processing book 703 / 30000 took 1.5645041465759277 seconds
# Processing book 704 / 30000 took 1.9624073505401611 seconds
# Processing book 705 / 30000 took 2.70853328704834 seconds
# Processing book 706 / 30000 took 1.5616559982299805 seconds
# Processing book 707 / 30000 took 1.1700820922851562 seconds
# Processing book 708 / 30000 took 2.517991542816162 seconds
# Processing book 709 / 30000 took 2.6200661659240723 seconds
# Processing book 710 / 30000 took 2.24379301071167 seconds
# Processing book 711 / 30000 took 1.9513771533966064 seconds
# Processing book 712 / 30000 took 2.024702548980713 seconds
# Processing book 713 / 30000 took 2.093315601348877 seconds
# Processing book 714 / 30000 took 3.105794668197632 seconds
# Processing book 715 / 30000 took 2.344996213912964 seconds
# Processing book 716 / 30000 took 2.520810604095459 seconds
# Processing book 717 / 30000 took 2.599097967147827 seconds
# Processing book 718 / 30000 took 1.5173113346099854 seconds
# Processing book 719 / 30000 took 1.9275851249694824 seconds
# Processing book 720 / 30000 took 2.631107807159424 seconds
# Processing book 721 / 30000 took 2.070384979248047 seconds
# Processing book 722 / 30000 took 1.832667589187622 seconds
# Processing book 723 / 30000 took 2.3118906021118164 seconds
# Processing book 724 / 30000 took 1.661994218826294 seconds
# Processing book 725 / 30000 took 1.7374482154846191 seconds
# Processing book 726 / 30000 took 1.59586501121521 seconds
# Processing book 727 / 30000 took 1.736745834350586 seconds
# Processing book 728 / 30000 took 8.45915961265564 seconds
# Processing book 729 / 30000 took 2.6037955284118652 seconds
# Processing book 730 / 30000 took 2.431185483932495 seconds
# Processing book 731 / 30000 took 1.9139466285705566 seconds
# Processing book 732 / 30000 took 2.054262161254883 seconds
# Processing book 733 / 30000 took 1.575131893157959 seconds
# Processing book 734 / 30000 took 1.7809233665466309 seconds
# Processing book 735 / 30000 took 1.1170322895050049 seconds
# Processing book 736 / 30000 took 1.8390157222747803 seconds
# Processing book 737 / 30000 took 1.9342055320739746 seconds
# Processing book 738 / 30000 took 2.3968210220336914 seconds
# Processing book 739 / 30000 took 1.9218144416809082 seconds
# Processing book 740 / 30000 took 2.5407533645629883 seconds
# Processing book 741 / 30000 took 2.7662596702575684 seconds
# Processing book 742 / 30000 took 2.2762088775634766 seconds
# Processing book 743 / 30000 took 1.8821589946746826 seconds
# Processing book 744 / 30000 took 2.7719194889068604 seconds
# Processing book 745 / 30000 took 2.505950689315796 seconds
# Processing book 746 / 30000 took 1.7238616943359375 seconds
# Processing book 747 / 30000 took 2.007045269012451 seconds
# Processing book 748 / 30000 took 1.5705714225769043 seconds
# Processing book 749 / 30000 took 1.1012282371520996 seconds
# Processing book 750 / 30000 took 1.513742208480835 seconds
# Processing book 751 / 30000 took 3.1976711750030518 seconds
# Processing book 752 / 30000 took 4.977926015853882 seconds
# Processing book 753 / 30000 took 3.016289234161377 seconds
# Processing book 754 / 30000 took 2.571065902709961 seconds
# Processing book 755 / 30000 took 2.547769069671631 seconds
# Processing book 756 / 30000 took 2.145366668701172 seconds
# Processing book 757 / 30000 took 1.2985739707946777 seconds
# Processing book 758 / 30000 took 1.8828747272491455 seconds
# Processing book 759 / 30000 took 1.1575548648834229 seconds
# Processing book 760 / 30000 took 2.1049671173095703 seconds
# Processing book 761 / 30000 took 2.104403495788574 seconds
# Processing book 762 / 30000 took 1.8448572158813477 seconds
# Processing book 763 / 30000 took 5.31325888633728 seconds
# Processing book 764 / 30000 took 2.105881452560425 seconds
# Processing book 765 / 30000 took 2.6247200965881348 seconds
# Processing book 766 / 30000 took 2.2100298404693604 seconds
# Processing book 767 / 30000 took 1.3608577251434326 seconds
# Processing book 768 / 30000 took 2.2360312938690186 seconds
# Processing book 769 / 30000 took 2.705134391784668 seconds
# Processing book 770 / 30000 took 1.7348792552947998 seconds
# Processing book 771 / 30000 took 1.4569919109344482 seconds
# Processing book 772 / 30000 took 1.388171672821045 seconds
# Processing book 773 / 30000 took 2.5069053173065186 seconds
# Processing book 774 / 30000 took 1.5491492748260498 seconds
# Processing book 775 / 30000 took 1.3050947189331055 seconds
# Processing book 776 / 30000 took 1.8946821689605713 seconds
# Processing book 777 / 30000 took 1.7264816761016846 seconds
# Processing book 778 / 30000 took 1.914612054824829 seconds
# Processing book 779 / 30000 took 2.242131233215332 seconds
# Processing book 780 / 30000 took 1.7845797538757324 seconds
# Processing book 781 / 30000 took 1.8636448383331299 seconds
# Processing book 782 / 30000 took 1.8549439907073975 seconds
# Processing book 783 / 30000 took 1.251899242401123 seconds
# Processing book 784 / 30000 took 3.1129252910614014 seconds
# Processing book 785 / 30000 took 1.465425968170166 seconds
# Processing book 786 / 30000 took 1.786623477935791 seconds
# Processing book 787 / 30000 took 1.75600004196167 seconds
# Processing book 788 / 30000 took 1.8015704154968262 seconds
# Processing book 789 / 30000 took 2.0770790576934814 seconds
# Processing book 790 / 30000 took 1.3345067501068115 seconds
# Processing book 791 / 30000 took 1.4510478973388672 seconds
# Processing book 792 / 30000 took 2.7072346210479736 seconds
# Processing book 793 / 30000 took 1.183013677597046 seconds
# Processing book 794 / 30000 took 2.504854917526245 seconds
# Processing book 795 / 30000 took 1.9202842712402344 seconds
# Processing book 796 / 30000 took 2.2836663722991943 seconds
# Processing book 797 / 30000 took 1.6773796081542969 seconds
# Processing book 798 / 30000 took 2.1931681632995605 seconds
# Processing book 799 / 30000 took 1.764765977859497 seconds
# Processing book 800 / 30000 took 1.9536173343658447 seconds
# Processing book 801 / 30000 took 2.1658220291137695 seconds
# Processing book 802 / 30000 took 2.785952568054199 seconds
# Processing book 803 / 30000 took 2.179779291152954 seconds
# Processing book 804 / 30000 took 2.6572680473327637 seconds
# Processing book 805 / 30000 took 2.0627105236053467 seconds
# Processing book 806 / 30000 took 1.2445216178894043 seconds
# ...
# Processing book 7239 / 30000 took 0.8610091209411621 seconds
# Processing book 7240 / 30000 took 0.8357744216918945 seconds
# Processing book 7241 / 30000 took 0.9410386085510254 seconds
# Processing book 7242 / 30000 took 1.0850534439086914 seconds
# Processing book 7243 / 30000 took 0.8539338111877441 seconds
# Processing book 7244 / 30000 took 1.0668385028839111 seconds
# Processing book 7245 / 30000 took 0.8341341018676758 seconds
# Processing book 7246 / 30000 took 1.3916347026824951 seconds
# Processing book 7247 / 30000 took 1.0134153366088867 seconds
# Processing book 7248 / 30000 took 0.81644606590271 seconds
# Processing book 7249 / 30000 took 0.936288595199585 seconds
# Processing book 7250 / 30000 took 1.3953337669372559 seconds
# Processing book 7251 / 30000 took 1.105767011642456 seconds
# Processing book 7252 / 30000 took 1.2962117195129395 seconds
# Processing book 7253 / 30000 took 1.1713314056396484 seconds
# Processing book 7254 / 30000 took 1.1269176006317139 seconds
# Processing book 7255 / 30000 took 1.0980305671691895 seconds
# Processing book 7256 / 30000 took 1.1988701820373535 seconds
# Processing book 7257 / 30000 took 1.015726089477539 seconds
# Processing book 7258 / 30000 took 0.9603161811828613 seconds
# Processing book 7259 / 30000 took 1.4591398239135742 seconds
# Processing book 7260 / 30000 took 0.8320419788360596 seconds
# Processing book 7261 / 30000 took 0.9349620342254639 seconds
# Processing book 7262 / 30000 took 1.1828265190124512 seconds
# Processing book 7263 / 30000 took 0.9050493240356445 seconds
# Processing book 7264 / 30000 took 0.9632203578948975 seconds
# Processing book 7265 / 30000 took 0.8524432182312012 seconds
# Processing book 7266 / 30000 took 0.7936491966247559 seconds
# Processing book 7267 / 30000 took 1.2359793186187744 seconds
# Processing book 7268 / 30000 took 1.9032015800476074 seconds
# Processing book 7269 / 30000 took 1.4093513488769531 seconds
# Processing book 7270 / 30000 took 0.8770327568054199 seconds
# Processing book 7271 / 30000 took 0.7799818515777588 seconds
# Processing book 7272 / 30000 took 1.1597545146942139 seconds
# Processing book 7273 / 30000 took 2.019043445587158 seconds
# Processing book 7274 / 30000 took 1.4634573459625244 seconds
# Processing book 7275 / 30000 took 1.0662047863006592 seconds
# Processing book 7276 / 30000 took 1.569671392440796 seconds
# Processing book 7277 / 30000 took 0.9867818355560303 seconds
# Processing book 7278 / 30000 took 0.8253364562988281 seconds
# Processing book 7279 / 30000 took 1.0341033935546875 seconds
# Processing book 7280 / 30000 took 1.0357086658477783 seconds
# Processing book 7281 / 30000 took 1.3679344654083252 seconds
# Processing book 7282 / 30000 took 0.8163614273071289 seconds
# Processing book 7283 / 30000 took 0.7890625 seconds
# Processing book 7284 / 30000 took 1.1180241107940674 seconds
# Processing book 7285 / 30000 took 1.127227544784546 seconds
# Processing book 7286 / 30000 took 1.2709953784942627 seconds
# Processing book 7287 / 30000 took 1.6527016162872314 seconds
# Processing book 7288 / 30000 took 0.7779576778411865 seconds
# Processing book 7289 / 30000 took 1.0092434883117676 seconds
# Processing book 7290 / 30000 took 1.0076425075531006 seconds
# Processing book 7291 / 30000 took 1.3479082584381104 seconds
# Processing book 7292 / 30000 took 0.8821871280670166 seconds
# Processing book 7293 / 30000 took 0.7719781398773193 seconds
# Processing book 7294 / 30000 took 1.4168882369995117 seconds
# Processing book 7295 / 30000 took 0.7559216022491455 seconds
# Processing book 7296 / 30000 took 1.0840613842010498 seconds
# Processing book 7297 / 30000 took 1.2901623249053955 seconds
# Processing book 7298 / 30000 took 1.090050458908081 seconds
# Processing book 7299 / 30000 took 1.0348572731018066 seconds
# Processing book 7300 / 30000 took 0.8029866218566895 seconds
# Processing book 7301 / 30000 took 0.9007995128631592 seconds
# Processing book 7302 / 30000 took 0.9339654445648193 seconds
# Processing book 7303 / 30000 took 0.9578499794006348 seconds
# Processing book 7304 / 30000 took 1.1807796955108643 seconds
# Processing book 7305 / 30000 took 1.1490659713745117 seconds
# Processing book 7306 / 30000 took 0.8762471675872803 seconds
# Processing book 7307 / 30000 took 0.8424458503723145 seconds
# Processing book 7308 / 30000 took 0.7445793151855469 seconds
# Processing book 7309 / 30000 took 1.1704716682434082 seconds
# Processing book 7310 / 30000 took 0.8954975605010986 seconds
# Processing book 7311 / 30000 took 1.9540486335754395 seconds
# Processing book 7312 / 30000 took 1.122652530670166 seconds
# Processing book 7313 / 30000 took 1.2199976444244385 seconds
# Processing book 7314 / 30000 took 1.3578357696533203 seconds
# Processing book 7315 / 30000 took 1.3351950645446777 seconds
# Processing book 7316 / 30000 took 1.0699875354766846 seconds
# Processing book 7317 / 30000 took 1.5966427326202393 seconds
# Processing book 7318 / 30000 took 0.8970928192138672 seconds
# Processing book 7319 / 30000 took 1.3499608039855957 seconds
# Processing book 7320 / 30000 took 1.0827910900115967 seconds
# Processing book 7321 / 30000 took 1.114825963973999 seconds
# Processing book 7322 / 30000 took 0.9298520088195801 seconds
# Processing book 7323 / 30000 took 1.506340742111206 seconds
# Processing book 7324 / 30000 took 1.160487174987793 seconds
# Processing book 7325 / 30000 took 0.9651663303375244 seconds
# Processing book 7326 / 30000 took 1.1250474452972412 seconds
# Processing book 7327 / 30000 took 1.5852015018463135 seconds
# Processing book 7328 / 30000 took 1.4134550094604492 seconds
# Processing book 7329 / 30000 took 1.0177743434906006 seconds
# Processing book 7330 / 30000 took 0.9125418663024902 seconds
# Processing book 7331 / 30000 took 1.0573084354400635 seconds
# Processing book 7332 / 30000 took 1.172755479812622 seconds
# Processing book 7333 / 30000 took 0.8066983222961426 seconds
# Processing book 7334 / 30000 took 0.8067028522491455 seconds
# Processing book 7335 / 30000 took 1.191532850265503 seconds
# Processing book 7336 / 30000 took 1.1640596389770508 seconds
# Processing book 7337 / 30000 took 0.9387691020965576 seconds
# Processing book 7338 / 30000 took 0.8290214538574219 seconds
# Processing book 7339 / 30000 took 0.745750904083252 seconds
# Processing book 7340 / 30000 took 0.9055976867675781 seconds
# Processing book 7341 / 30000 took 1.0431878566741943 seconds
# Processing book 7342 / 30000 took 0.9620084762573242 seconds
# Processing book 7343 / 30000 took 1.4409589767456055 seconds
# Processing book 7344 / 30000 took 1.2167439460754395 seconds
# Processing book 7345 / 30000 took 1.1525905132293701 seconds
# Processing book 7346 / 30000 took 0.8788928985595703 seconds
# Processing book 7347 / 30000 took 1.0971741676330566 seconds
# Processing book 7348 / 30000 took 0.6946845054626465 seconds
# Processing book 7349 / 30000 took 0.9172854423522949 seconds
# Processing book 7350 / 30000 took 1.062974452972412 seconds
# Processing book 7351 / 30000 took 0.9111776351928711 seconds
# Processing book 7352 / 30000 took 1.1646137237548828 seconds
# Processing book 7353 / 30000 took 0.9709646701812744 seconds
# Processing book 7354 / 30000 took 0.8285963535308838 seconds
# Processing book 7355 / 30000 took 0.8315176963806152 seconds
# Processing book 7356 / 30000 took 0.7358806133270264 seconds
# Processing book 7357 / 30000 took 0.9649820327758789 seconds
# Processing book 7358 / 30000 took 0.8749997615814209 seconds
# Processing book 7359 / 30000 took 1.003188133239746 seconds
# Processing book 7360 / 30000 took 1.2002344131469727 seconds
# Processing book 7361 / 30000 took 0.8193731307983398 seconds
# Processing book 7362 / 30000 took 0.9988398551940918 seconds
# Processing book 7363 / 30000 took 0.9999969005584717 seconds
# Processing book 7364 / 30000 took 1.610499382019043 seconds
# Processing book 7365 / 30000 took 0.8716847896575928 seconds
# Processing book 7366 / 30000 took 0.7741742134094238 seconds
# Processing book 7367 / 30000 took 0.8478856086730957 seconds
# Processing book 7368 / 30000 took 0.45215415954589844 seconds
# Processing book 7369 / 30000 took 0.8900713920593262 seconds
# Processing book 7370 / 30000 took 0.9636619091033936 seconds
# Processing book 7371 / 30000 took 0.8254001140594482 seconds
# Processing book 7372 / 30000 took 1.4117438793182373 seconds
# Processing book 7373 / 30000 took 1.0919609069824219 seconds
# Processing book 7374 / 30000 took 0.9859411716461182 seconds
# Processing book 7375 / 30000 took 0.8069603443145752 seconds
# Processing book 7376 / 30000 took 0.7745435237884521 seconds
# Processing book 7377 / 30000 took 0.900296688079834 seconds
# Processing book 7378 / 30000 took 0.901268482208252 seconds
# Processing book 7379 / 30000 took 1.1483705043792725 seconds
# Processing book 7380 / 30000 took 0.989149808883667 seconds
# Processing book 7381 / 30000 took 0.9810616970062256 seconds
# Processing book 7382 / 30000 took 1.512735366821289 seconds
# Processing book 7383 / 30000 took 1.1500282287597656 seconds
# Processing book 7384 / 30000 took 0.7349967956542969 seconds
# Processing book 7385 / 30000 took 1.1150181293487549 seconds
# Processing book 7386 / 30000 took 0.814971923828125 seconds
# Processing book 7387 / 30000 took 1.1620123386383057 seconds
# Processing book 7388 / 30000 took 0.9400272369384766 seconds
# Processing book 7389 / 30000 took 1.1359953880310059 seconds
# Processing book 7390 / 30000 took 0.9316880702972412 seconds
# Processing book 7391 / 30000 took 1.1932835578918457 seconds
# Processing book 7392 / 30000 took 1.0440452098846436 seconds
# Processing book 7393 / 30000 took 0.9423909187316895 seconds
# Processing book 7394 / 30000 took 0.9309768676757812 seconds
# Processing book 7395 / 30000 took 1.1960065364837646 seconds
# Processing book 7396 / 30000 took 0.8370318412780762 seconds
# Processing book 7397 / 30000 took 0.7651371955871582 seconds
# Processing book 7398 / 30000 took 1.013566017150879 seconds
# Processing book 7399 / 30000 took 1.0852410793304443 seconds
# Processing book 7400 / 30000 took 1.165785551071167 seconds
# Processing book 7401 / 30000 took 1.0255935192108154 seconds
# Processing book 7402 / 30000 took 0.9293215274810791 seconds
# Processing book 7403 / 30000 took 0.906153678894043 seconds
# Processing book 7404 / 30000 took 0.5240118503570557 seconds
# Processing book 7405 / 30000 took 1.828904628753662 seconds
# Processing book 7406 / 30000 took 1.0110499858856201 seconds
# Processing book 7407 / 30000 took 1.3782973289489746 seconds
# Processing book 7408 / 30000 took 1.013209581375122 seconds
# Processing book 7409 / 30000 took 1.2752254009246826 seconds
# Processing book 7410 / 30000 took 0.8174405097961426 seconds
# Processing book 7411 / 30000 took 1.309302806854248 seconds
# Processing book 7412 / 30000 took 1.3844666481018066 seconds
# Processing book 7413 / 30000 took 0.9248924255371094 seconds
# Processing book 7414 / 30000 took 1.4622068405151367 seconds
# Processing book 7415 / 30000 took 1.192443609237671 seconds
# Processing book 7416 / 30000 took 0.7872674465179443 seconds
# Processing book 7417 / 30000 took 0.9541199207305908 seconds
# Processing book 7418 / 30000 took 0.8018386363983154 seconds
# Processing book 7419 / 30000 took 1.0344629287719727 seconds
# Processing book 7420 / 30000 took 0.9125449657440186 seconds
# Processing book 7421 / 30000 took 1.1249926090240479 seconds
# Processing book 7422 / 30000 took 1.2862708568572998 seconds
# Processing book 7423 / 30000 took 1.0249874591827393 seconds
# Processing book 7424 / 30000 took 1.3440659046173096 seconds
# Processing book 7425 / 30000 took 1.6480798721313477 seconds
# Processing book 7426 / 30000 took 0.8422844409942627 seconds
# Processing book 7427 / 30000 took 0.9791281223297119 seconds
# Processing book 7428 / 30000 took 1.1579387187957764 seconds
# Processing book 7429 / 30000 took 1.2505779266357422 seconds
# Processing book 7430 / 30000 took 1.544933557510376 seconds
# Processing book 7431 / 30000 took 1.4569134712219238 seconds
# Processing book 7432 / 30000 took 1.0624244213104248 seconds
# Processing book 7433 / 30000 took 1.8120098114013672 seconds
# Processing book 7434 / 30000 took 2.086158275604248 seconds
# Processing book 7435 / 30000 took 0.9410333633422852 seconds
# Processing book 7436 / 30000 took 1.151606798171997 seconds
# Processing book 7437 / 30000 took 1.56424880027771 seconds
# Processing book 7438 / 30000 took 1.4876091480255127 seconds
# Processing book 7439 / 30000 took 1.4900567531585693 seconds
# Processing book 7440 / 30000 took 1.0209324359893799 seconds
# Processing book 7441 / 30000 took 1.0745790004730225 seconds
# Processing book 7442 / 30000 took 0.7419180870056152 seconds
# Processing book 7443 / 30000 took 1.0441968441009521 seconds
# Processing book 7444 / 30000 took 0.9928560256958008 seconds
# Processing book 7445 / 30000 took 1.0241491794586182 seconds
# Processing book 7446 / 30000 took 1.050856113433838 seconds
# Processing book 7447 / 30000 took 1.1483471393585205 seconds
# Processing book 7448 / 30000 took 0.9277222156524658 seconds
# Processing book 7449 / 30000 took 1.1820175647735596 seconds
# Processing book 7450 / 30000 took 1.5361649990081787 seconds
# Processing book 7451 / 30000 took 0.9729931354522705 seconds
# Processing book 7452 / 30000 took 0.9579496383666992 seconds
# Processing book 7453 / 30000 took 1.213911771774292 seconds
# Processing book 7454 / 30000 took 0.8681390285491943 seconds
# Processing book 7455 / 30000 took 0.9940962791442871 seconds
# Processing book 7456 / 30000 took 1.388934850692749 seconds
# Processing book 7457 / 30000 took 1.3930597305297852 seconds
# Processing book 7458 / 30000 took 0.7968945503234863 seconds
# Processing book 7459 / 30000 took 1.4320025444030762 seconds
# Processing book 7460 / 30000 took 1.103290319442749 seconds
# Processing book 7461 / 30000 took 0.9950573444366455 seconds
# Processing book 7462 / 30000 took 1.1189656257629395 seconds
# Processing book 7463 / 30000 took 1.1829533576965332 seconds
# Processing book 7464 / 30000 took 0.9785747528076172 seconds
# Processing book 7465 / 30000 took 1.2820470333099365 seconds
# Processing book 7466 / 30000 took 0.9550695419311523 seconds
# Processing book 7467 / 30000 took 0.8869788646697998 seconds
# Processing book 7468 / 30000 took 0.9423666000366211 seconds
# Processing book 7469 / 30000 took 1.1958129405975342 seconds
# Processing book 7470 / 30000 took 1.0301778316497803 seconds
# Processing book 7471 / 30000 took 1.0568389892578125 seconds
# Processing book 7472 / 30000 took 0.9242415428161621 seconds
# Processing book 7473 / 30000 took 0.9907968044281006 seconds
# Processing book 7474 / 30000 took 0.9853758811950684 seconds
# Processing book 7475 / 30000 took 0.9706802368164062 seconds
# Processing book 7476 / 30000 took 0.92893385887146 seconds
# Processing book 7477 / 30000 took 1.1963911056518555 seconds
# Processing book 7478 / 30000 took 1.5472793579101562 seconds
# Processing book 7479 / 30000 took 0.8428499698638916 seconds
# Processing book 7480 / 30000 took 1.1420338153839111 seconds
# Processing book 7481 / 30000 took 0.8622934818267822 seconds
# Processing book 7482 / 30000 took 0.7967503070831299 seconds
# Processing book 7483 / 30000 took 1.0655121803283691 seconds
# Processing book 7484 / 30000 took 0.9150741100311279 seconds
# Processing book 7485 / 30000 took 1.1586778163909912 seconds
# Processing book 7486 / 30000 took 0.8617751598358154 seconds
# Processing book 7487 / 30000 took 1.8290252685546875 seconds
# Processing book 7488 / 30000 took 1.7621655464172363 seconds
# Processing book 7489 / 30000 took 1.5236668586730957 seconds
# Processing book 7490 / 30000 took 0.5980334281921387 seconds
# Processing book 7491 / 30000 took 1.0354626178741455 seconds
# Processing book 7492 / 30000 took 1.2498648166656494 seconds
# Processing book 7493 / 30000 took 1.0160667896270752 seconds
# Processing book 7494 / 30000 took 0.9715619087219238 seconds
# Processing book 7495 / 30000 took 1.2058498859405518 seconds
# Processing book 7496 / 30000 took 0.969789981842041 seconds
# Processing book 7497 / 30000 took 1.31797194480896 seconds
# Processing book 7498 / 30000 took 0.8411979675292969 seconds
# Processing book 7499 / 30000 took 1.2827568054199219 seconds
# Processing book 7500 / 30000 took 0.909003734588623 seconds
# --- 15389.512818813324 seconds ---

# %% [markdown]
# The preceding code took 3 hours to run for the 30.000 books. Now it is time to append all the information in one single table.
#
# As mentioned, to create a single data frame with the information parsed from the 30.000 books, we uploaded each .tsv file and appended them in a pandas object. Later, we deleted duplicated caused for multiple runs over the same book. Then we keep only the books with valid information since some links didn't have the correct structure to be scraped. Afterwards, we validated if the plot of the books was in English. To do so, we used the `langdetect` to get the descriptions matching with *en* (English). As a final step, we saved the file in a .tsv file that contains the whole books.

# %%
start_time = time.time()
# Upload both parts of the books' information providing the corresponding name of each column
colnames = ['book_title', 'bookSeries', 'bookAuthors', 'ratingValue', 'ratingCount', 'reviewCount', 'Plot', 'NumberofPages', 'PublishingDate', 'Characters', 'Setting','language','Url']
data = pd.read_csv("data/tsv _files/final_df_1.tsv", sep="\t", names=colnames, header=None, encoding='utf-8')
data_part2 = pd.read_csv("data/tsv _files/final_df_2.tsv", sep="\t", names=colnames, header=None, encoding='utf-8')
data_part3 = pd.read_csv("data/tsv _files/final_df_3.tsv", sep="\t", names=colnames, header=None, encoding='utf-8')
data_part4 = pd.read_csv("data/tsv _files/final_df_4.tsv", sep="\t", names=colnames, header=None, encoding='utf-8')

# Append all dataframes in a single one
data = data.append(data_part2)
data = data.append(data_part3)
data = data.append(data_part4)
del data_part2, data_part3, data_part4

# Delete duplicates caused by multiple runs over the same book
data = data.drop_duplicates()

# Keep the books that have valid information
data = data[data['book_title'].notnull()]

# Check that all the books has an URL
data = data[data['Url'].notnull()]

# Keep only the books which plot is in english
data = data[data['language'] == 'en']

# Export final table to be used in the next points
data.to_csv("data/final_file/all_books_information.tsv", sep = "\t", index=False)
print(data.shape)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (26568, 13)
# --- 1.931851863861084 seconds ---

# %% [markdown]
# Finally, we scraped the information about 26568 books (removing those without information and which plot is not in English). Now we are ready to proceed with the creation of our search engines.

# %% [markdown]
# # 2. Search Engine

# %% [markdown]
# More libraries are required for this part.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from collections import Counter

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Import required libraries
import time
import csv
from bs4 import BeautifulSoup
import requests
import pathlib
import math
import os
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Text pre-processing
#
# Now, we want to create two different Search Engines that, given as input a query, return the books that match the query.
#
# First, we must pre-process all the information collected for each book by
# 1. Removing stopwords
# 2. Removing punctuation
# 3. Stemming
# 4. More ?

# %%
books_info = pd.read_csv("all_books_information.tsv", sep="\t", header=0, encoding='utf8', nrows=1000)

stop_words = set(stopwords.words('english'))
stemming = PorterStemmer()
books_info.head(5)
# Out:
#                                   book_title  ...                                                Url
# 0                           The Hunger Games  ...  https://www.goodreads.com/book/show/2767052-th...
# 1  Harry Potter and the Order of the Phoenix  ...  https://www.goodreads.com/book/show/2.Harry_Po...
# 2                      To Kill a Mockingbird  ...  https://www.goodreads.com/book/show/2657.To_Ki...
# 3                        Pride and Prejudice  ...  https://www.goodreads.com/book/show/1885.Pride...
# 4                                   Twilight  ...  https://www.goodreads.com/book/show/41865.Twil...
#
# [5 rows x 13 columns]

# %%
def tokenize_row(row):
    tokens = nltk.word_tokenize(row)
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

def stem_row(row):
    stemmed_list = [stemming.stem(word) for word in row]
    return (stemmed_list)

def rm_stopwords_row(row):
    meaningful_words = [w for w in row if not w in stop_words]
    return (meaningful_words)


books_info['Plot'] = books_info['Plot'].apply(tokenize_row)

print(books_info['Plot'][0])

books_info['Plot'] = books_info['Plot'].apply(stem_row)

print(books_info['Plot'][0])

books_info['Plot'] = books_info['Plot'].apply(rm_stopwords_row)

print(books_info['Plot'][0])
# Out:
# ['In', 'the', 'ruins', 'of', 'a', 'place', 'once', 'known', 'as', 'North', 'America', 'lies', 'the', 'nation', 'of', 'Panem', 'a', 'shining', 'Capitol', 'surrounded', 'by', 'twelve', 'outlying', 'districts', 'The', 'Capitol', 'is', 'harsh', 'and', 'cruel', 'and', 'keeps', 'the', 'districts', 'in', 'line', 'by', 'forcing', 'them', 'all', 'to', 'send', 'one', 'boy', 'and', 'one', 'girl', 'between', 'the', 'ages']
# ['In', 'the', 'ruin', 'of', 'a', 'place', 'onc', 'known', 'as', 'north', 'america', 'lie', 'the', 'nation', 'of', 'panem', 'a', 'shine', 'capitol', 'surround', 'by', 'twelv', 'outli', 'district', 'the', 'capitol', 'is', 'harsh', 'and', 'cruel', 'and', 'keep', 'the', 'district', 'in', 'line', 'by', 'forc', 'them', 'all', 'to', 'send', 'one', 'boy', 'and', 'one', 'girl', 'between', 'the', 'age']
# ['In', 'ruin', 'place', 'onc', 'known', 'north', 'america', 'lie', 'nation', 'panem', 'shine', 'capitol', 'surround', 'twelv', 'outli', 'district', 'capitol', 'harsh', 'cruel', 'keep', 'district', 'line', 'forc', 'send', 'one', 'boy', 'one', 'girl', 'age']

# %% [markdown]
# ## 2.1. Conjunctive query

# %% [markdown]
# ### 2.1.1 Creating the index

# %% [markdown]
# First we compute the list called vocabulary containing all the possible words in our corpus.

# %%
vocabulary = []
for plot in books_info['Plot']:
  for word in plot :
    if word not in vocabulary:
      vocabulary.append(word)

# %% [markdown]
# We then create the Inverted index by zipping matching the vocabulary list with the document_ids containing the word. There are no duplicates in our dict (ie. if a word appears two time in a plot it makes no difference it this first index)

# %%
dict_values=[[]for _ in range(len(vocabulary))] #for each word of the vocabulary we'll save which plot contain it (document_id)

document_id=0
for plot in books_info['Plot']:
  for w0rd in plot :
    index=vocabulary.index(w0rd)
    if document_id not in dict_values[index] :
     dict_values[index].append(document_id)
  document_id+=1

Inverted_index=dict(zip(vocabulary, dict_values))

# %% [markdown]
# ### 2.1.2 Executing the query

# %% [markdown]
# We ask the user to input a query. Note that the query words need to go through the stemming process too otherwise we will not be able to match them properly.

# %%
query = input("What kind of book are you looking for ?\n")
query=nltk.word_tokenize(query)
query = [stemming.stem(word) for word in query]
print(query)
# Out:
# What kind of book are you looking for ?
# survival game
# ['surviv', 'game']

# %%
results=[]
for word in query:
  if word in Inverted_index.keys():
    for document_id in Inverted_index[word] :
      results.append(books_info[['book_title','Plot','Url']].iloc[document_id])

result_df= pd.concat(results, axis=1)
result_df=result_df.T #we transpose the dataframe to plot it as specified in the hw description
result_df.head(20)
# Out:
#                       book_title  ...                                                Url
# 52                    Life of Pi  ...  https://www.goodreads.com/book/show/4214.Life_...
# 66                Watership Down  ...  https://www.goodreads.com/book/show/76620.Wate...
# 68                  Little Women  ...  https://www.goodreads.com/book/show/1934.Littl...
# 84                Angela's Ashes  ...  https://www.goodreads.com/book/show/252577.Ang...
# 175            The Titan's Curse  ...  https://www.goodreads.com/book/show/561456.The...
# 179         The Call of the Wild  ...  https://www.goodreads.com/book/show/1852.The_C...
# 219                Catching Fire  ...  https://www.goodreads.com/book/show/6148028-ca...
# 235     Man's Search for Meaning  ...  https://www.goodreads.com/book/show/4069.Man_s...
# 315     A Court of Mist and Fury  ...  https://www.goodreads.com/book/show/17927395-a...
# 318                   Mockingjay  ...  https://www.goodreads.com/book/show/7260188-mo...
# 323             The Power of One  ...  https://www.goodreads.com/book/show/122.The_Po...
# 367            The Complete Maus  ...  https://www.goodreads.com/book/show/15195.The_...
# 381                    Crescendo  ...  https://www.goodreads.com/book/show/7791997-cr...
# 392              Robinson Crusoe  ...  https://www.goodreads.com/book/show/2932.Robin...
# 397                         Room  ...  https://www.goodreads.com/book/show/31685789-r...
# 411                   The Plague  ...  https://www.goodreads.com/book/show/11989.The_...
# 431  All the Light We Cannot See  ...  https://www.goodreads.com/book/show/18143977-a...
# 444               Redeeming Love  ...  https://www.goodreads.com/book/show/11422.Rede...
# 453  A Court of Thorns and Roses  ...  https://www.goodreads.com/book/show/16096824-a...
# 466                     I, Robot  ...  https://www.goodreads.com/book/show/41804.I_Ro...
#
# [20 rows x 3 columns]

# %% [markdown]
# ## 2.2  Conjunctive query & Ranking score

# %% [markdown]
# ## 2.2.1 Inverted index and TF-IDF score

# %% [markdown]
# Our goal is to get a matching score for each book and to plot the top-k article. To compute this matching score, we use the tfidf score and the cosine similarity.
#
# Check this document for more info on matching score computation (material recommanded by the professor) : https://nlp.stanford.edu/IR-book/pdf/06vect.pdf

# %%
document_nb=books_info.shape[0] #this is necessary to compute the idf

new_dict_values=[[]for _ in range(len(vocabulary))]
document_id=0
for plot in books_info['Plot']:
  for w0rd in plot :
    index=vocabulary.index(w0rd)
    new_dict_values[index].append(document_id)
  document_id+=1

list=[]
for i in range(len(new_dict_values)):
  list.append(Counter(new_dict_values[i]))

word_occurences=dict(zip(vocabulary,list))

# %%
document_id=0
tfidf_values=[[]for _ in range(len(vocabulary))]
info=[]
words_already_seen=[]
for plot in books_info['Plot']:
  words_nb=len(plot)
  for w0rd in plot :
    if w0rd not in words_already_seen:
      words_already_seen.append(w0rd)
      term_id=vocabulary.index(w0rd)
      tf=word_occurences[w0rd][document_id]/words_nb
      idf=np.log(document_nb/len(word_occurences[w0rd]))
      tfidf=tf*idf
      info.append('document_'+str(document_id))
      info.append(tfidf)
      tfidf_values[term_id].append(info)
      info=[]
  words_already_seen=[]
  document_id+=1

Inverted_index_tfidf=dict(zip(vocabulary,tfidf_values))

print(Inverted_index_tfidf)
# Out:
# {'In': [['document_0', 0.06682558549676333], ['document_8', 0.05383172165017046], ['document_16', 0.05699829351194519], ['document_19', 0.05099847314226675], ['document_20', 0.06251425740019795], ['document_22', 0.10475362050843982], ['document_49', 0.06682558549676333], ['document_50', 0.15299541942680026], ['document_67', 0.1019969462845335], ['document_72', 0.05536977084017533], ['document_81', 0.05383172165017046], ['document_86', 0.04969081998477273], ['document_89', 0.05699829351194519], ['document_91', 0.05536977084017533], ['document_99', 0.08425834693070158], ['document_100', 0.05237681025421991], ['document_103', 0.05872551452745869], ['document_114', 0.04844854948515342], ['document_122', 0.05383172165017046], ['document_135', 0.05699829351194519], ['document_145', 0.0745362299771591], ['document_146', 0.05536977084017533], ['document_148', 0.05536977084017533], ['document_162', 0.09453375509298227], ['document_165', 0.05237681025421991], ['document_170', 0.047266877546491136], ['document_177', 0.04614147570014611], ['document_185', 0.06459806598020455], ['document_206', 0.05237681025421991], ['document_209', 0.05237681025421991], ['document_222', 0.05383172165017046], ['document_225', 0.05536977084017533], ['document_227', 0.05699829351194519], ['document_232', 0.1019969462845335], ['document_236', 0.06251425740019795], ['document_237', 0.05237681025421991], ['document_241', 0.04614147570014611], ['document_251', 0.05536977084017533], ['document_252', 0.04969081998477273], ['document_258', 0.045068418125724104], ['document_262', 0.05699829351194519], ['document_265', 0.05699829351194519], ['document_268', 0.05536977084017533], ['document_271', 0.06251425740019795], ['document_276', 0.05872551452745869], ['document_279', 0.05699829351194519], ['document_291', 0.10475362050843982], ['document_323', 0.04844854948515342], ['document_326', 0.06056068685644177], ['document_327', 0.09228295140029222], ['document_332', 0.08074758247525568], ['document_334', 0.06056068685644177], ['document_355', 0.04969081998477273], ['document_364', 0.05237681025421991], ['document_379', 0.04969081998477273], ['document_393', 0.04969081998477273], ['document_400', 0.05536977084017533], ['document_403', 0.05099847314226675], ['document_405', 0.05699829351194519], ['document_411', 0.05237681025421991], ['document_417', 0.05383172165017046], ['document_419', 0.06921221355021916], ['document_423', 0.04969081998477273], ['document_430', 0.05699829351194519], ['document_439', 0.04969081998477273], ['document_441', 0.14534564845546025], ['document_446', 0.07177562886689394], ['document_457', 0.05536977084017533], ['document_463', 0.11745102905491737], ['document_473', 0.05237681025421991], ['document_482', 0.05699829351194519], ['document_483', 0.04614147570014611], ['document_484', 0.05099847314226675], ['document_492', 0.09453375509298227], ['document_500', 0.06056068685644177], ['document_501', 0.05699829351194519], ['document_509', 0.06056068685644177], ['document_513', 0.05099847314226675], ['document_514', 0.06459806598020455], ['document_517', 0.05872551452745869], ['document_525', 0.06459806598020455], ['document_533', 0.08808827179118803], ['document_560', 0.04969081998477273], ['document_571', 0.05099847314226675], ['document_573', 0.06056068685644177], ['document_575', 0.04969081998477273], ['document_577', 0.10766344330034092], ['document_582', 0.06921221355021916], ['document_585', 0.04969081998477273], ['document_586', 0.05699829351194519], ['document_589', 0.04969081998477273], ['document_597', 0.16149516495051136], ['document_598', 0.06459806598020455], ['document_600', 0.04969081998477273], ['document_607', 0.05099847314226675], ['document_613', 0.05383172165017046], ['document_628', 0.05237681025421991], ['document_633', 0.06921221355021916], ['document_637', 0.05237681025421991], ['document_644', 0.047266877546491136], ['document_646', 0.04844854948515342], ['document_648', 0.05383172165017046], ['document_655', 0.107663443300 ...

# %% [markdown]
# # 3. Define a new score!

# %% [markdown]
# # 4. Make a nice visualization!

# %% [markdown]
# # 5. Algorithmic Question

# %% [markdown]
# ## 1. Write a recursive program that, given a string, computes the length of the subsequence of maximum length that is in alphabetical order.
# Try some examples. Are the examples of short strings correct? Can you find examples that your algorithm does not terminate in reasonable time?

# %% [markdown]
# To calculate the maximum length of a subsequence of characters that is in alphabetical order we created three functions as follows:
#
# `alphabet_pos`: Receives a string and changes the characters by positions of the letters in the alphabet (mapping).
#
# `max_len_sub_alpha_recursive`: Receives a position ($i$) of the character where the string is included, and a list representing the numbers mapped from letters. This is a recursive function that evaluates the maximum length of a subsequence of characters that is in alphabetical order that finishes in the letter of the $i^{th}$ position of the string.
#
# `review_string`: Receives a string and executes the `max_len_sub_alpha` function for each character of the string ($n$ times).
#
# All the previous functions can be found in the file our_functions.py.

# %%
start_time = time.time()
# Set the desired string
string = "ABCDE"
# Apply function to string
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.review_string(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 5
# --- 0.0 seconds ---

# %%
start_time = time.time()
# Set the desired string
string = "KBEAXCZ"
# Apply function to string
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.review_string(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 4
# --- 0.0 seconds ---

# %% [markdown]
# Looking at the two short examples, we can see that the results are correct since considering the string ABCDE the maximum length of a subsequence of characters that is in alphabetical order is 5. Also, regarding the string K**BE**A**X**C**Z**, the maximum length of a subsequence of characters that is in alphabetical order is 4.

# %%
start_time = time.time()
# Set the desired string
string = "KJHDSALKJHALJHFDKJDLKHSL"
# Apply function to string
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.review_string(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 6
# --- 0.0019936561584472656 seconds ---

# %%
start_time = time.time()
# Set the desired string
string = "KJHDSALKJHALJHFDKJDLKHSLKJHDSAKJDSAADSHJHGDSAJHGDSAJDSAJH"
# Apply function to string
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.review_string(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 6
# --- 0.023902177810668945 seconds ---

# %%
start_time = time.time()
# Set the desired string
string = "KJHDSALKJHALJHFDKJDLKHSLKJHDSAKJDSAADSHJHGDSAJHGDSAJDSAJHGDSAJHGJHDSKJHLSAKJHDSKJHDSAKJHSAKJWWIUYSKAKJHDLKJHSAB"
# Apply function to string
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.review_string(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 10
# --- 3.685804605484009 seconds ---

# %% [markdown]
# Now, we considered 3 more examples, where we can see how the longer the string, the larger the execution time is. It makes us believe that the complexity of the recursive program could be exponential.

# %% [markdown]
# ## 2. Show that the running time of the algorithm is exponential.

# %% [markdown]
# Let's consider $T(N)$ as the running time of the algorithm for the given length of the string ($N$). Taking into account that the function `max_len_sub_alpha_recursive` evaluates the maximum length of a subsequence of characters that is in alphabetical order that finishes in the letter of the  $i^{th}$ position of the string, it can be shown that:
#
#
# $T(N) = T(N-1) + T(N-2) + T(N-3) + T(N-4) + ... + T(1) + T(0)$
#
# Now, replacing $T(N-1)$ in the previous formula, we have that:
#
# $T(N) = [T(N-2) + T(N-3) + T(N-4) + ... + T(1) + T(0)] + T(N-2) + T(N-3) + T(N-4) + ... + T(1) + T(0)$
#
# $T(N) = 2[T(N-2) + T(N-3) + T(N-4) + ... + T(1) + T(0)]$
#
# Again, replacing $T(N-1)$ in the previous formula, we have that:
#
# $T(N) = 4[T(N-3) + T(N-4) + ... + T(1) + T(0)]$
#
# If we continue to do the replacements in the previous formula, we get that:
#
# $T(N) = 8[T(N-4) + ... + T(1) + T(0)]$
#
# $T(N) = 16[T(N-5) + ... + T(1) + T(0)]$
#
# $T(N) = 2^î[T(N-(i-1)]$
#
# Finally, when taking the value of N we get:
#
# $T(N) = 2^N[T(N-(N-1)]$
#
# $T(N) = 2^N[T(1)]$
#
# $T(N) = 2^N$
#
# In the end, we obtained that the complexity of the algorithm is $O(2^n)$
#
# But, it is important to take into account that we executed the previous algorithm $n$ times, that corresponds to each letter of the substring. The latter means that the final complexity of the algorithm is $O(n2^n)$. Effectively, the running time of the algorithm is exponential.

# %% [markdown]
# ## 3. Write a program that computes the length of the subsequence of maximum length, using dynamic programming.

# %% [markdown]
# To calculate the maximum length of a subsequence of characters that is in alphabetical order, but using dynamic programming, we created one functions as follows:
#
# `max_len_sub_alpha_dyn_prog`: Receives a string and maps its letters to numbers (using the function `alphabet_pos`). Later we defined an auxiliary array to store the maximum length that is finding when visiting the positions of the arrays with two for loops to evaluate the conditions defined for a subsequence to be in alphabetical order.
#
# The previous function can be found in the file our_functions.py.

# %%
start_time = time.time()
# Set the desired string
string = "ABCDE"
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.max_len_sub_alpha_dyn_prog(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 5
# --- 0.0009949207305908203 seconds ---

# %%
start_time = time.time()
# Set the desired string
string = "KBEAXCZ"
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.max_len_sub_alpha_dyn_prog(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 4
# --- 0.0009925365447998047 seconds ---

# %% [markdown]
# Looking at the two short examples, we can see that the results are correct since considering the string ABCDE the maximum length of a subsequence of characters that is in alphabetical order is 5. Besides, regarding the string K**BE**A**X**C**Z**, the maximum length of a subsequence of characters that is in alphabetical order is 4. The results are consistent with those obtained with the recursive algorithm.

# %%
start_time = time.time()
# Set the desired string
string = "KJHDSALKJHALJHFDKJDLKHSL"
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.max_len_sub_alpha_dyn_prog(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 6
# --- 0.0009989738464355469 seconds ---

# %%
start_time = time.time()
# Set the desired string
string = "KJHDSALKJHALJHFDKJDLKHSLKJHDSAKJDSAADSHJHGDSAJHGDSAJDSAJH"
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.max_len_sub_alpha_dyn_prog(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 6
# --- 0.0009565353393554688 seconds ---

# %%
start_time = time.time()
# Set the desired string
string = "KJHDSALKJHALJHFDKJDLKHSLKJHDSAKJDSAADSHJHGDSAJHGDSAJDSAJHGDSAJHGJHDSKJHLSAKJHDSKJHDSAKJHSAKJWWIUYSKAKJHDLKJHSAB"
print("The maximum length of a subsequence of characters that is in alfabetical order is", our_functions.max_len_sub_alpha_dyn_prog(string))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The maximum length of a subsequence of characters that is in alfabetical order is 10
# --- 0.0009975433349609375 seconds ---

# %% [markdown]
# Finally, considering the same examples that in the previous exercise of the application of the recursive program, the execution time remains almost the same when increasing the number of letters considerably in the string. It shows that the dynamic program is way better than the recursive one since the complexity of the former is of polynomial order.

# %% [markdown]
# ## 4. What is its runtime complexity?

# %% [markdown]
# With the previous algorithm, we can see that:
#
# - The first for loop goes from the second letter to the $n^{th}$ letter ($n$ is the length of the string). The previous means that it visits $n - 1$ letters.
# - The second for loop (that is contained in the first loop) goes from the first letter to the $i^{th}$. That means that, when $i = n$, it will go from the first letter to the $(n-1)^{th}$ letter.
#
# Then, the running time can be seen as:
#
# $T(N) <= (N-1) * (N-1)$
#
# $T(N) <= (N^2 - 2N + 1)$
#
# And taking the worst case, we have that the running time is:
# $O(n^2)$

# %% [markdown]
# # BONUS

# %% [markdown]
# To prove that given
#
# $X[i] =$ "the length of the longest sequence of characters in alphabetical order that terminates at the $i^{th}$ character".
#
# $X[i] = 1 + max(X[j]; j = 0, ..., i-1 ,$ such that $S[j]<S[i])$
#
# $X[i] = 1,$ if there does not exist such a j
#
# We will use the induction approach as follows:
#
# - First, we prove the base case. It is that $X[1] = 1$. This one is correct because it is taking the first element as a subsequence of itself of length 1.
#
# - Now we use an inductive case. For that, we can assume that $X[1], ..., X[i-1]$ are correct.
# - Then, at index $i$ (the next index) the first possible subsequence is the element $S[i]$ itself of length 1.
# - Another possibility is a subsequence starting before and finishing at $i$, with the last index included being $j$.
# - The latter only happens when $S[j] < S[i]$, because the order needs to be alphabetical.
# - If the previous occurs, then its maximum length is $X[j] + 1$ since we appended the letter at index $i$.
# - So $X[i]$ is correct because the algorithm calculates the maximum of all these possibilities.
